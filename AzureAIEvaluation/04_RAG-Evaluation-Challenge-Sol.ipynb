# %% [markdown]
# # RAG Evaluation Solution

# %% [markdown]
# ## Load Azure Configurations

# %%
from dotenv import load_dotenv
import os

load_dotenv() # take environment variables from .env.

azure_openai_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
azure_openai_key = os.getenv("AZURE_OPENAI_API_KEY")
azure_openai_deployment = os.getenv("AZURE_OPENAI_CHAT_DEPLOYMENT_NAME")
azure_openai_embeddings_deployment = os.getenv("AZURE_OPENAI_EMBEDDINGS_DEPLOYMENT")
azure_openai_api_version = "2024-10-01-preview"
azure_search_service_endpoint = os.getenv("AZURE_SEARCH_SERVICE_ENDPOINT")
azure_search_service_admin_key = os.getenv("AZURE_SEARCH_ADMIN_KEY")
azure_search_service_index_name = "product-index-challenge"
azure_storage_connection_string = os.getenv("AZURE_STORAGE_CONNECTION_STRING")

model_config = {
    "azure_endpoint": azure_openai_endpoint,
    "api_key": azure_openai_key,
    "azure_deployment": azure_openai_deployment,
}

azure_subscription_id = os.getenv("AZURE_SUBSCRIPTION_ID")
azure_resource_group_name = os.getenv("AZURE_RESOURCE_GROUP_NAME")
azure_project_name = os.getenv("AZURE_PROJECT_NAME")

azure_ai_project = {
    "subscription_id": azure_subscription_id,
    "resource_group_name": azure_resource_group_name,
    "project_name": azure_project_name,
}

# %% [markdown]
# ## Load Documents

# %%
from langchain_community.document_loaders import DirectoryLoader

path = "../Data/products/"
loader = DirectoryLoader(path, glob="**/*.pdf")
docs = loader.load()

# %% [markdown]
# ## Prepare the Language Model

# %%
from langchain_openai import AzureChatOpenAI
from langchain_openai import AzureOpenAIEmbeddings
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper

generator_llm = LangchainLLMWrapper(AzureChatOpenAI(
    openai_api_version=azure_openai_api_version,
    azure_endpoint=azure_openai_endpoint,
    azure_deployment=azure_openai_deployment,
    model=azure_openai_deployment,
    validate_base_url=False,
    api_key=azure_openai_key
))

# init the embeddings for answer_relevancy, answer_correctness and answer_similarity
generator_embeddings = LangchainEmbeddingsWrapper(AzureOpenAIEmbeddings(
    openai_api_version=azure_openai_api_version,
    azure_endpoint=azure_openai_endpoint,
    azure_deployment=azure_openai_embeddings_deployment,
    model=azure_openai_embeddings_deployment,
    api_key=azure_openai_key
))

# %% [markdown]
# ## Generate the Test Set

# %%
from ragas.testset import TestsetGenerator

generator = TestsetGenerator(llm=generator_llm, embedding_model=generator_embeddings)
dataset = generator.generate_with_langchain_docs(docs, testset_size=10)
# Out:
# Applying HeadlinesExtractor:   0%|          | 0/20 [00:00<?, ?it/s]
# Applying HeadlineSplitter:   0%|          | 0/20 [00:00<?, ?it/s]
# Applying SummaryExtractor:   0%|          | 0/20 [00:00<?, ?it/s]
# Applying CustomNodeFilter:   0%|          | 0/54 [00:00<?, ?it/s]
# Applying [EmbeddingExtractor, ThemesExtractor, NERExtractor]:   0%|          | 0/128 [00:00<?, ?it/s]
# Applying [CosineSimilarityBuilder, OverlapScoreBuilder]:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating personas:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating Scenarios:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating Samples:   0%|          | 0/12 [00:00<?, ?it/s]

# %% [markdown]
# ## Save just the query and ground truth to a JSONL file for evaluation

# %%
import pandas as pd

df = dataset.to_pandas()

# Create DataFrame
df = dataset.to_pandas()

# Function to clean text
def clean_text(text_list):
    cleaned_text_list = []
    for text in text_list:
        # Remove the UUID (assuming it's always at the start and followed by two newlines)
        cleaned_text = text.split('\n\n', 1)[-1]
        cleaned_text_list.append(cleaned_text)
    return cleaned_text_list

# Apply the function to the 'reference_contexts' column to remove UUID at the start
df['reference_contexts'] = df['reference_contexts'].apply(clean_text)

# Save to CSV file
df.to_csv('../Data/output/product-evalset.csv', index=False)

# Create a new DataFrame for EvalCollection
eval_collection = pd.DataFrame(columns=['query', 'response', 'context', 'ground_truth'])

# Populate the new DataFrame
eval_collection['query'] = df['user_input']
eval_collection['ground_truth'] = df['reference']
eval_collection['response'] = ''
eval_collection['context'] = ''

# Save the DataFrame as a JSONL file
eval_collection.to_json('../Data/output/product-eval.jsonl', orient='records', lines=True)

# %% [markdown]
# ## Generate the Response and Context from the RAG Application

# %%
from azure.search.documents import SearchClient
from azure.search.documents.models import VectorizableTextQuery
from azure.core.credentials import AzureKeyCredential
from openai import AzureOpenAI

# Get credential from Azure AI Search Admin key
credential = AzureKeyCredential(azure_search_service_admin_key)
search_client = SearchClient(endpoint=azure_search_service_endpoint, 
                             credential=credential, 
                             index_name=azure_search_service_index_name)

# Azure OpenAI client
openai_client = AzureOpenAI(
    # to get version: https://learn.microsoft.com/en-us/azure/ai-services/openai/api-version-deprecation
    api_version=azure_openai_api_version,
    azure_endpoint=azure_openai_endpoint,
    api_key=azure_openai_key)

# Provide instructions to the model
SYSTEM_PROMPT="""
You are an AI assistant that helps users learn from the information found in the source material.
Answer the query using only the sources provided below.
Use bullets if the answer has multiple points.
If the answer is longer than 3 sentences, provide a summary.
Answer ONLY with the facts listed in the list of sources below. Cite your source when you answer the question
If there isn't enough information below, say you don't know.
Do not generate answers that don't use the sources below.
Query: {query}
Sources:\n{sources}
"""
# Iterate over each row in eval_collection
for index, row in eval_collection.iterrows():
    # User Query
    query = row['query']  

    # Convert query into vector form
    vector_query = VectorizableTextQuery(text=query, 
                                        k_nearest_neighbors=50, 
                                        fields="text_vector",
                                        weight=1)

    results = search_client.search(
        query_type="semantic", 
        semantic_configuration_name='my-semantic-config',
        search_text=query,
        vector_queries= [vector_query],
        select=["title","chunk"],
        top=3,
    )

    # Use a unique separator to make the sources distinct. 
    # We chose repeated equal signs (=) followed by a newline because it's unlikely the source documents contain this sequence.
    sources_formatted = "=================\n".join([f'TITLE: {document["title"]}, CONTENT: {document["chunk"]}' for document in results])

    # Update the context in the DataFrame
    eval_collection.at[index, 'context'] = sources_formatted

    response = openai_client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": SYSTEM_PROMPT.format(query=query, sources=sources_formatted)
            }
        ],
        model=azure_openai_deployment
    )

    # Update the response in the DataFrame
    eval_collection.at[index, 'response'] = response.choices[0].message.content

# Save the updated DataFrame as a JSONL file
eval_collection.to_json('../Data/output/product-eval.jsonl', orient='records', lines=True)

# Print success message
print("EvalCollection has been saved to product-eval.jsonl")
# Out:
# EvalCollection has been saved to product-eval.jsonl

# %% [markdown]
# ## Run evaluation and view in Azure AI Foundry

# %%
from azure.ai.evaluation import evaluate
from azure.ai.evaluation import GroundednessEvaluator, RetrievalEvaluator, RelevanceEvaluator, CoherenceEvaluator, FluencyEvaluator, SimilarityEvaluator, F1ScoreEvaluator
from azure.ai.evaluation import RougeScoreEvaluator, RougeType
from azure.ai.evaluation import BleuScoreEvaluator
from azure.ai.evaluation import MeteorScoreEvaluator
from azure.ai.evaluation import GleuScoreEvaluator
from azure.ai.evaluation import ViolenceEvaluator, HateUnfairnessEvaluator, SelfHarmEvaluator,SexualEvaluator
from azure.identity import DefaultAzureCredential
import pandas as pd

groundedness_eval = GroundednessEvaluator(model_config)
retrieval_eval = RetrievalEvaluator(model_config)
relevance_eval = RelevanceEvaluator(model_config)
coherence_eval = CoherenceEvaluator(model_config)
fluency_eval = FluencyEvaluator(model_config)
similarity_eval = SimilarityEvaluator(model_config)
f1_eval = F1ScoreEvaluator()
rouge_eval = RougeScoreEvaluator(rouge_type=RougeType.ROUGE_1)
bleu_eval = BleuScoreEvaluator()
meteor_eval = MeteorScoreEvaluator(
    alpha=0.9,
    beta=3.0,
    gamma=0.5
)
gleu_eval = GleuScoreEvaluator()
violence_eval = ViolenceEvaluator(azure_ai_project=azure_ai_project, credential=DefaultAzureCredential())
hateunfairness_eval = HateUnfairnessEvaluator(azure_ai_project=azure_ai_project, credential=DefaultAzureCredential())
selfharm_eval = SelfHarmEvaluator(azure_ai_project=azure_ai_project, credential=DefaultAzureCredential

# 2025-04-18 02:18:57 +0000   30609 execution.bulk     INFO     Finished 2 / 12 lines.
# 2025-04-18 02:18:57 +0000   30609 execution.bulk     INFO     Average execution time for completed lines: 17.84 seconds. Estimated time for incomplete lines: 178.4 seconds.
# 2025-04-18 02:19:04 +0000   30609 execution.bulk     INFO     Finished 3 / 12 lines.
# 2025-04-18 02:19:04 +0000   30609 execution.bulk     INFO     Average execution time for completed lines: 14.26 seconds. Estimated time for incomplete lines: 128.34 seconds.
# 2025-04-18 02:19:06 +0000   30609 execution.bulk     INFO     Finished 4 / 12 lines.
# 2025-04-18 02:19:06 +0000   30609 execution.bulk     INFO     Average execution time for completed lines: 11.16 seconds. Estimated time for incomplete lines: 89.28 seconds.
# 2025-04-18 02:19:06 +0000   30609 execution.bulk     INFO     Finished 5 / 12 lines.
# 2025-04-18 02:19:06 +0000   30609 execution.bulk     INFO     Average execution time for completed lines: 8.93 seconds. Estimated time for incomplete lines: 62.51 seconds.
# 2025-04-18 02:19:07 +0000   30609 execution.bulk     INFO     Finished 6 / 12 lines.
# 2025-04-18 02:19:07 +0000   30609 execution.bulk     INFO     Average execution time for completed lines: 7.61 seconds. Estimated time for incomplete lines: 45.66 seconds.
# 2025-04-18 02:19:24 +0000   30609 execution.bulk     INFO     Finished 7 / 12 lines.
# 2025-04-18 02:19:24 +0000   30609 execution.bulk     INFO     Average execution time for completed lines: 8.93 seconds. Estimated time for incomplete lines: 44.65 seconds.
# 2025-04-18 02:19:24 +0000   30609 execution.bulk     INFO     Finished 8 / 12 lines.
# 2025-04-18 02:19:24 +0000   30609 execution.bulk     INFO     Average execution time for completed lines: 7.82 seconds. Estimated time for incomplete lines: 31.28 seconds.
# 2025-04-18 02:19:24 +0000   30609 execution.bulk     INFO     Finished 9 / 12 lines.
# 2025-04-18 02:19:24 +0000   30609 execution.bulk     INFO     Average execution time for completed lines: 6.95 seconds. Estimated time for incomplete lines: 20.85 seconds.
# 2025-04-18 02:19:24 +0000   30609 execution.bulk     INFO     Finished 10 / 12 lines.
# 2025-04-18 02:19:24 +0000   30609 execution.bulk     INFO     Average execution time for completed lines: 6.26 seconds. Estimated time for incomplete lines: 12.52 seconds.
# 2025-04-18 02:19:31 +0000   30609 execution.bulk     INFO     Finished 11 / 12 lines.
# 2025-04-18 02:19:31 +0000   30609 execution.bulk     INFO     Average execution time for completed lines: 6.32 seconds. Estimated time for incomplete lines: 6.32 seconds.
# 2025-04-18 02:19:35 +0000   30609 execution.bulk     INFO     Finished 12 / 12 lines.
# 2025-04-18 02:19:35 +0000   30609 execution.bulk     INFO     Average execution time for completed lines: 6.14 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_squvo56l_20250418_021821_404289"
# Run status: "Completed"
# Start time: "2025-04-18 02:18:21.401621+00:00"
# Duration: "0:01:14.106282"
# Output path: "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_squvo56l_20250418_021821_404289"
#
# ======= Combined Run Summary (Per Evaluator) =======
#
# {
#     "groundedness": {
#         "status": "Completed",
#         "duration": "0:00:07.930241",
#         "completed_lines": 12,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_b4jyszlt_20250418_021814_148731"
#     },
#     "retrieval": {
#         "status": "Completed",
#         "duration": "0:00:07.851749",
#         "completed_lines": 12,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_kxbwae07_20250418_021814_147964"
#     },
#     "relevance": {
#         "status": "Completed",
#         "duration": "0:00:06.844302",
#         "completed_lines": 12,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_9rr72m52_20250418_021814_147571"
#     },
#     "coherence": {
#         "status": "Completed",
#         "duration": "0:00:07.133319",
#         "completed_lines": 12,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ckizlfa7_20250418_021814_147822"
#     },
#     "fluency": {
#         "status": "Completed",
#         "duration": "0:00:05.611102",
#         "completed_lines": 12,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_as4eca07_20250418_021814_151105"
#     },
#     "similarity": {
#         "status": "Completed",
#         "duration": "0:00:03.653895",
#         "completed_lines": 12,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_similarity_similarity_asyncsimilarityevaluator_v700l6ek_20250418_021814_150421"
#     },
#     "f1_score": {
#         "status": "Completed",
#         "duration": "0:00:01.088861",
#         "completed_lines": 12,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_f1_score_f1_score_asyncf1scoreevaluator_me7szprc_20250418_021817_866442"
#     },
#     "rouge_score": {
#         "status": "Completed",
#         "duration": "0:00:01.045018",
#         "completed_lines": 12,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_rouge_rouge_asyncrougescoreevaluator_u652i0z1_20250418_021818_971292"
#     },
#     "bleu_score": {
#         "status": "Completed",
#         "duration": "0:00:01.180288",
#         "completed_lines": 12,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator_17fx954l_20250418_021819_775346"
#     },
#     "meteor_score": {
#         "status": "Completed",
#         "duration": "0:00:07.800045",
#         "completed_lines": 12,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_meteor_meteor_asyncmeteorscoreevaluator_mi2r8bzj_20250418_021820_038113"
#     },
#     "gleu_score": {
#         "status": "Completed",
#         "duration": "0:00:01.598865",
#         "completed_lines": 12,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_gleu_gleu_asyncgleuscoreevaluator_3bcdu5w1_20250418_021821_383918"
#     },
#     "violence_score": {
#         "status": "Completed",
#         "duration": "0:01:14.106282",
#         "completed_lines": 12,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_squvo56l_20250418_021821_404289"
#     },
#     "hateunfairness_score": {
#         "status": "Completed",
#         "duration": "0:01:09.069671",
#         "completed_lines": 12,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_vsgqanet_20250418_021821_448728"
#     },
#     "selfharm_score": {
#         "status": "Completed",
#         "duration": "0:01:12.886460",
#         "completed_lines": 12,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_u5vvex8s_20250418_021822_314712"
#     },
#     "sexual_score": {
#         "status": "Completed",
#         "duration": "0:01:07.667722",
#         "completed_lines": 12,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_j7b9z0bo_20250418_021822_584922"
#     }
# }
#
# ====================================================
