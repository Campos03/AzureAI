# %% [markdown]
# # RAG Evaluation

# %% [markdown]
# ## Load Dependencies

# %%
# %pip install azure-ai-evaluation
# %pip install promptflow-azure
# Out:
# Requirement already satisfied: azure-ai-evaluation in /home/codespace/.python/current/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: promptflow-devkit>=1.15.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-evaluation) (1.16.2)
# Requirement already satisfied: promptflow-core>=1.15.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-evaluation) (1.16.2)
# Requirement already satisfied: pyjwt>=2.8.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-evaluation) (2.10.1)
# Requirement already satisfied: azure-identity>=1.16.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-evaluation) (1.19.0)
# Requirement already satisfied: azure-core>=1.30.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-evaluation) (1.32.0)
# Requirement already satisfied: nltk>=3.9.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-evaluation) (3.9.1)
# Requirement already satisfied: azure-storage-blob>=12.10.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-evaluation) (12.24.0)
# Requirement already satisfied: requests>=2.21.0 in /home/codespace/.local/lib/python3.12/site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /home/codespace/.local/lib/python3.12/site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (4.12.2)
# Requirement already satisfied: cryptography>=2.5 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (44.0.2)
# Requirement already satisfied: msal>=1.30.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (1.31.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (1.2.0)
# Requirement already satisfied: isodate>=0.6.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-storage-blob>=12.10.0->azure-ai-evaluation) (0.7.2)
# Requirement already satisfied: click in /home/codespace/.python/current/lib/python3.12/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (8.1.7)
# Requirement already satisfied: joblib in /home/codespace/.local/lib/python3.12/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/codespace/.python/current/lib/python3.12/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (2024.11.6)
# Requirement already satisfied: tqdm in /home/codespace/.python/current/lib/python3.12/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (4.67.1)
# Requirement already satisfied: docstring_parser in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (0.16)
# Requirement already satisfied: fastapi<1.0.0,>=0.109.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (0.115.6)
# Requirement already satisfied: filetype>=1.2.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (1.2.0)
# Requirement already satisfied: flask<4.0.0,>=2.2.3 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (3.1.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (4.23.0)
# Requirement already satisfied: promptflow-tracing==1.16.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (1.16.2)
# Requirement already satisfied: psutil in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (5.9.8)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (2.9.0.post0)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-core>=1.15.0->azure-ai-evaluation) (0.18.6)
# Requirement already satisfied: openai in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-tracing==1.16.2->promptflow-core>=1.15.0->azure-ai-evaluation) (1.68.2)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-tracing==1.16.2->promptflow-core>=1.15.0->azure-ai-evaluation) (1.31.1)
# Requirement already satisfied: tiktoken>=0.4.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-tracing==1.16.2->promptflow-core>=1.15.0->azure-ai-evaluation) (0.8.0)
# Requirement already satisfied: argcomplete>=3.2.3 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.5.2)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.0.0b32)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /home/codespace/.local/lib/python3.12/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.4.6)
# Requirement already satisfied: filelock<4.0.0,>=3.4.0 in /home/codespace/.local/lib/python3.12/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.13.1)
# Requirement already satisfied: flask-cors<6.0.0,>=5.0.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (5.0.0)
# Requirement already satisfied: flask-restx<2.0.0,>=1.2.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.3.0)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.24 in /home/codespace/.local/lib/python3.12/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.1.43)
# Requirement already satisfied: httpx>=0.25.1 in /home/codespace/.local/lib/python3.12/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.27.2)
# Requirement already satisfied: keyring<25.0.0,>=24.2.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (24.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.5 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.23.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.31.1)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in /home/codespace/.local/lib/python3.12/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (2.2.3)
# Collecting pillow<11.0.0,>=10.1.0 (from promptflow-devkit>=1.15.0->azure-ai-evaluation)
#   Downloading pillow-10.4.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: pydash<8.0.0,>=6.0.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (7.0.7)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.0.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.48 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (2.0.36)
# Requirement already satisfied: strictyaml<2.0.0,>=1.5.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.7.3)
# Requirement already satisfied: tabulate<1.0.0,>=0.9.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.9.0)
# Requirement already satisfied: waitress<4.0.0,>=3.0.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.0.2)
# Requirement already satisfied: fixedint==0.1.6 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.1.6)
# Requirement already satisfied: msrest>=0.6.10 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.7.1)
# Requirement already satisfied: opentelemetry-api~=1.26 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.27.0)
# Requirement already satisfied: cffi>=1.12 in /home/codespace/.local/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation) (1.17.1)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core>=1.15.0->azure-ai-evaluation) (0.41.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /home/codespace/.python/current/lib/python3.12/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core>=1.15.0->azure-ai-evaluation) (2.10.4)
# Requirement already satisfied: Werkzeug>=3.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /home/codespace/.python/current/lib/python3.12/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation) (1.9.0)
# Requirement already satisfied: aniso8601>=0.82 in /home/codespace/.python/current/lib/python3.12/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (9.0.1)
# Requirement already satisfied: pytz in /home/codespace/.local/lib/python3.12/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (2024.2)
# Requirement already satisfied: importlib-resources in /home/codespace/.python/current/lib/python3.12/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (6.4.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from gitpython<4.0.0,>=3.1.24->promptflow-devkit>=1.15.0->azure-ai-evaluation) (4.0.11)
# Requirement already satisfied: anyio in /home/codespace/.python/current/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (4.9.0)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.0.5)
# Requirement already satisfied: idna in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.10)
# Requirement already satisfied: sniffio in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.1->promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.15.0->azure-ai-evaluation) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.15.0->azure-ai-evaluation) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.15.0->azure-ai-evaluation) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.15.0->azure-ai-evaluation) (0.20.0)
# Requirement already satisfied: jaraco.classes in /home/codespace/.python/current/lib/python3.12/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.4.0)
# Requirement already satisfied: SecretStorage>=3.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.3.3)
# Requirement already satisfied: jeepney>=0.4.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (0.8.0)
# Requirement already satisfied: packaging>=17.0 in /home/codespace/.local/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.5->promptflow-devkit>=1.15.0->azure-ai-evaluation) (24.1)
# Requirement already satisfied: portalocker<3,>=1.4 in /home/codespace/.python/current/lib/python3.12/site-packages (from msal-extensions>=1.2.0->azure-identity>=1.16.0->azure-ai-evaluation) (2.10.1)
# Requirement already satisfied: deprecated>=1.2.6 in /home/codespace/.python/current/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.2.15)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/codespace/.python/current/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.31.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.31.1)
# Requirement already satisfied: opentelemetry-proto==1.31.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.31.1)
# Collecting protobuf<6.0,>=5.0 (from opentelemetry-proto==1.31.1->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation)
#   Using cached protobuf-5.29.4-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: numpy>=1.26.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.26.4)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit>=1.15.0->azure-ai-evaluation) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation) (2.2.3)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/codespace/.python/current/lib/python3.12/site-packages (from ruamel.yaml<1.0.0,>=0.17.10->promptflow-core>=1.15.0->azure-ai-evaluation) (0.2.12)
# Requirement already satisfied: greenlet!=0.4.17 in /home/codespace/.python/current/lib/python3.12/site-packages (from sqlalchemy<3.0.0,>=1.4.48->promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.1.1)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/codespace/.python/current/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (1.17.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.24->promptflow-devkit>=1.15.0->azure-ai-evaluation) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.12/site-packages (from Jinja2>=3.1.2->flask<4.0.0,>=2.2.3->promptflow-core>=1.15.0->azure-ai-evaluation) (2.1.5)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (2.0.0)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from opentelemetry-api~=1.26->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (8.4.0)
# Collecting opentelemetry-api~=1.26 (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation)
#   Using cached opentelemetry_api-1.31.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in /home/codespace/.python/current/lib/python3.12/site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.16.2->promptflow-core>=1.15.0->azure-ai-evaluation) (0.52b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core>=1.15.0->azure-ai-evaluation) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core>=1.15.0->azure-ai-evaluation) (2.27.2)
# Requirement already satisfied: more-itertools in /home/codespace/.python/current/lib/python3.12/site-packages (from jaraco.classes->keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.15.0->azure-ai-evaluation) (10.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from openai->promptflow-tracing==1.16.2->promptflow-core>=1.15.0->azure-ai-evaluation) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from openai->promptflow-tracing==1.16.2->promptflow-core>=1.15.0->azure-ai-evaluation) (0.8.2)
# Requirement already satisfied: zipp>=0.5 in /home/codespace/.python/current/lib/python3.12/site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api~=1.26->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.21.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.15.0->azure-ai-evaluation) (3.2.2)
# Downloading pillow-10.4.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 22.7 MB/s eta 0:00:00
# Using cached opentelemetry_api-1.31.1-py3-none-any.whl (65 kB)
# Using cached protobuf-5.29.4-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Installing collected packages: protobuf, pillow, opentelemetry-api
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.6
#     Uninstalling protobuf-4.25.6:
#       Successfully uninstalled protobuf-4.25.6
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.27.0
#     Uninstalling opentelemetry-api-1.27.0:
#       Successfully uninstalled opentelemetry-api-1.27.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-instrumentation-asgi 0.50b0 requires opentelemetry-instrumentation==0.50b0, but you have opentelemetry-instrumentation 0.52b1 which is incompatible.
# opentelemetry-instrumentation-asgi 0.50b0 requires opentelemetry-semantic-conventions==0.50b0, but you have opentelemetry-semantic-conventions 0.52b1 which is incompatible.
# opentelemetry-instrumentation-asgi 0.50b0 requires opentelemetry-util-http==0.50b0, but you have opentelemetry-util-http 0.52b1 which is incompatible.
# opentelemetry-instrumentation-fastapi 0.50b0 requires opentelemetry-instrumentation==0.50b0, but you have opentelemetry-instrumentation 0.52b1 which is incompatible.
# opentelemetry-instrumentation-fastapi 0.50b0 requires opentelemetry-semantic-conventions==0.50b0, but you have opentelemetry-semantic-conventions 0.52b1 which is incompatible.
# opentelemetry-instrumentation-fastapi 0.50b0 requires opentelemetry-util-http==0.50b0, but you have opentelemetry-util-http 0.52b1 which is incompatible.
# autogen-core 0.4.0.dev13 requires opentelemetry-api~=1.27.0, but you have opentelemetry-api 1.31.1 which is incompatible.
# autogen-core 0.4.0.dev13 requires pillow>=11.0.0, but you have pillow 10.4.0 which is incompatible.
# autogen-core 0.4.0.dev13 requires protobuf~=4.25.1, but you have protobuf 5.29.4 which is incompatible.
# Successfully installed opentelemetry-api-1.31.1 pillow-10.4.0 protobuf-5.29.4
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: promptflow-azure in /home/codespace/.python/current/lib/python3.12/site-packages (1.16.2)
# Requirement already satisfied: azure-ai-ml<2.0.0,>=1.14.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-azure) (1.22.4)
# Requirement already satisfied: azure-core<2.0.0,>=1.26.4 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-azure) (1.32.0)
# Requirement already satisfied: azure-cosmos<5.0.0,>=4.5.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-azure) (4.9.0)
# Requirement already satisfied: azure-identity<2.0.0,>=1.12.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-azure) (1.19.0)
# Requirement already satisfied: azure-storage-blob<13.0.0,>=12.17.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (12.24.0)
# Requirement already satisfied: promptflow-devkit<2.0.0,>=1.16.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-azure) (1.16.2)
# Requirement already satisfied: pyjwt<3.0.0,>=2.4.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-azure) (2.10.1)
# Requirement already satisfied: pyyaml>=5.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (6.0.2)
# Requirement already satisfied: msrest>=0.6.18 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.7.1)
# Requirement already satisfied: azure-mgmt-core>=1.3.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.5.0)
# Requirement already satisfied: marshmallow>=3.5 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (3.23.1)
# Requirement already satisfied: jsonschema>=4.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.23.0)
# Requirement already satisfied: tqdm in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.67.1)
# Requirement already satisfied: strictyaml in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.7.3)
# Requirement already satisfied: colorama in /home/codespace/.local/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.4.6)
# Requirement already satisfied: azure-storage-file-share in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (12.20.0)
# Requirement already satisfied: azure-storage-file-datalake>=12.2.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (12.18.0)
# Requirement already satisfied: pydash>=6.0.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (7.0.7)
# Requirement already satisfied: isodate in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.7.2)
# Requirement already satisfied: azure-common>=1.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.1.28)
# Requirement already satisfied: typing-extensions in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.12.2)
# Requirement already satisfied: opencensus-ext-azure in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.1.13)
# Requirement already satisfied: opencensus-ext-logging in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.1.1)
# Requirement already satisfied: requests>=2.21.0 in /home/codespace/.local/lib/python3.12/site-packages (from azure-core<2.0.0,>=1.26.4->promptflow-azure) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /home/codespace/.local/lib/python3.12/site-packages (from azure-core<2.0.0,>=1.26.4->promptflow-azure) (1.16.0)
# Requirement already satisfied: cryptography>=2.5 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-identity<2.0.0,>=1.12.0->promptflow-azure) (44.0.2)
# Requirement already satisfied: msal>=1.30.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-identity<2.0.0,>=1.12.0->promptflow-azure) (1.31.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-identity<2.0.0,>=1.12.0->promptflow-azure) (1.2.0)
# Requirement already satisfied: argcomplete>=3.2.3 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.5.2)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.0.0b32)
# Requirement already satisfied: filelock<4.0.0,>=3.4.0 in /home/codespace/.local/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.13.1)
# Requirement already satisfied: flask-cors<6.0.0,>=5.0.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (5.0.0)
# Requirement already satisfied: flask-restx<2.0.0,>=1.2.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.3.0)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.24 in /home/codespace/.local/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.1.43)
# Requirement already satisfied: httpx>=0.25.1 in /home/codespace/.local/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.27.2)
# Requirement already satisfied: keyring<25.0.0,>=24.2.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (24.3.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.31.1)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in /home/codespace/.local/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2.2.3)
# Requirement already satisfied: pillow<11.0.0,>=10.1.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (10.4.0)
# Requirement already satisfied: promptflow-core<2.0.0,>=1.16.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.16.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.0.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.48 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2.0.36)
# Requirement already satisfied: tabulate<1.0.0,>=0.9.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.9.0)
# Requirement already satisfied: waitress<4.0.0,>=3.0.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.0.2)
# Requirement already satisfied: aiohttp>=3.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (3.11.16)
# Requirement already satisfied: fixedint==0.1.6 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.1.6)
# Requirement already satisfied: opentelemetry-api~=1.26 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.31.1)
# Requirement already satisfied: opentelemetry-sdk~=1.26 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.31.1)
# Requirement already satisfied: psutil~=5.9 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (5.9.8)
# Requirement already satisfied: cffi>=1.12 in /home/codespace/.local/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity<2.0.0,>=1.12.0->promptflow-azure) (1.17.1)
# Requirement already satisfied: Flask>=0.9 in /home/codespace/.python/current/lib/python3.12/site-packages (from flask-cors<6.0.0,>=5.0.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.1.0)
# Requirement already satisfied: aniso8601>=0.82 in /home/codespace/.python/current/lib/python3.12/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (9.0.1)
# Requirement already satisfied: werkzeug!=2.0.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.1.3)
# Requirement already satisfied: pytz in /home/codespace/.local/lib/python3.12/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2024.2)
# Requirement already satisfied: importlib-resources in /home/codespace/.python/current/lib/python3.12/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (6.4.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from gitpython<4.0.0,>=3.1.24->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (4.0.11)
# Requirement already satisfied: anyio in /home/codespace/.python/current/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (4.9.0)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.0.5)
# Requirement already satisfied: idna in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.10)
# Requirement already satisfied: sniffio in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.1->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.20.0)
# Requirement already satisfied: jaraco.classes in /home/codespace/.python/current/lib/python3.12/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.4.0)
# Requirement already satisfied: SecretStorage>=3.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.3.3)
# Requirement already satisfied: jeepney>=0.4.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.8.0)
# Requirement already satisfied: packaging>=17.0 in /home/codespace/.local/lib/python3.12/site-packages (from marshmallow>=3.5->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (24.1)
# Requirement already satisfied: portalocker<3,>=1.4 in /home/codespace/.python/current/lib/python3.12/site-packages (from msal-extensions>=1.2.0->azure-identity<2.0.0,>=1.12.0->promptflow-azure) (2.10.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from msrest>=0.6.18->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (2.0.0)
# Requirement already satisfied: deprecated>=1.2.6 in /home/codespace/.python/current/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.2.15)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/codespace/.python/current/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.31.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.31.1)
# Requirement already satisfied: opentelemetry-proto==1.31.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.31.1)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from opentelemetry-proto==1.31.1->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (5.29.4)
# Requirement already satisfied: numpy>=1.26.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2024.2)
# Requirement already satisfied: docstring_parser in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.16)
# Requirement already satisfied: fastapi<1.0.0,>=0.109.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.115.6)
# Requirement already satisfied: filetype>=1.2.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.2.0)
# Requirement already satisfied: promptflow-tracing==1.16.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.16.2)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.18.6)
# Requirement already satisfied: openai in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-tracing==1.16.2->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.68.2)
# Requirement already satisfied: tiktoken>=0.4.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from promptflow-tracing==1.16.2->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /home/codespace/.python/current/lib/python3.12/site-packages (from sqlalchemy<3.0.0,>=1.4.48->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.1.1)
# Requirement already satisfied: opencensus<1.0.0,>=0.11.4 in /home/codespace/.python/current/lib/python3.12/site-packages (from opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.11.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/codespace/.python/current/lib/python3.12/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from aiohttp>=3.0->azure-core[aio]>=1.30.0; extra == "aio"->azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (1.18.3)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity<2.0.0,>=1.12.0->promptflow-azure) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/codespace/.python/current/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.17.0)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.41.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /home/codespace/.python/current/lib/python3.12/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2.10.4)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from Flask>=0.9->flask-cors<6.0.0,>=5.0.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from Flask>=0.9->flask-cors<6.0.0,>=5.0.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /home/codespace/.python/current/lib/python3.12/site-packages (from Flask>=0.9->flask-cors<6.0.0,>=5.0.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (8.1.7)
# Requirement already satisfied: blinker>=1.9 in /home/codespace/.python/current/lib/python3.12/site-packages (from Flask>=0.9->flask-cors<6.0.0,>=5.0.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.9.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.24->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (5.0.1)
# Requirement already satisfied: opencensus-context>=0.1.3 in /home/codespace/.python/current/lib/python3.12/site-packages (from opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (2.24.0)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from opentelemetry-api~=1.26->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (8.4.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in /home/codespace/.python/current/lib/python3.12/site-packages (from opentelemetry-sdk~=1.26->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.52b1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.18->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (3.2.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/codespace/.python/current/lib/python3.12/site-packages (from ruamel.yaml<1.0.0,>=0.17.10->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.2.12)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/codespace/.local/lib/python3.12/site-packages (from werkzeug!=2.0.0->flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2.1.5)
# Requirement already satisfied: more-itertools in /home/codespace/.python/current/lib/python3.12/site-packages (from jaraco.classes->keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (10.5.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /home/codespace/.python/current/lib/python3.12/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.25.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (2.37.0)
# Requirement already satisfied: zipp>=0.5 in /home/codespace/.python/current/lib/python3.12/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api~=1.26->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (3.21.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2.27.2)
# Requirement already satisfied: regex>=2022.1.18 in /home/codespace/.python/current/lib/python3.12/site-packages (from tiktoken>=0.4.0->promptflow-tracing==1.16.2->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (2024.11.6)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from openai->promptflow-tracing==1.16.2->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from openai->promptflow-tracing==1.16.2->promptflow-core<2.0.0,>=1.16.2->promptflow-devkit<2.0.0,>=1.16.2->promptflow-azure) (0.8.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/codespace/.python/current/lib/python3.12/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /home/codespace/.python/current/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load Azure configurations
#
# You always need to run this!

# %%
from dotenv import load_dotenv
import os

load_dotenv() # take environment variables from .env.

azure_openai_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
azure_openai_key = os.getenv("AZURE_OPENAI_API_KEY")
azure_openai_deployment = os.getenv("AZURE_OPENAI_CHAT_DEPLOYMENT_NAME")

model_config = {
    "azure_endpoint": azure_openai_endpoint,
    "api_key": azure_openai_key,
    "azure_deployment": azure_openai_deployment,
}

azure_subscription_id = os.getenv("AZURE_SUBSCRIPTION_ID")
azure_resource_group_name = os.getenv("AZURE_RESOURCE_GROUP_NAME")
azure_project_name = os.getenv("AZURE_PROJECT_NAME")

azure_ai_project = {
    "subscription_id": azure_subscription_id,
    "resource_group_name": azure_resource_group_name,
    "project_name": azure_project_name,
}

# %% [markdown]
# ## Get the first row to test

# %%
import json

# Load JSON data from a file
with open('../Data/output/nasaeval.jsonl', 'r') as file:
    data = [json.loads(line) for line in file]

# Assuming the JSON structure is a list of dictionaries and we want the first row
first_row = data[0]

# Assign values to variables
context = first_row['context']
query = first_row['query']
ground_truth = first_row['ground_truth']
response = first_row['response']

print("Context: ", context)
print("Query: ", query)
print("Ground Truth: ", ground_truth)
print("Response: ", response)
# Out:
# Context:  TITLE: page-11.pdf, CONTENT: A
# T
#
# M
# O
#
# S
# P
#
# H
# E
#
# R
# E
#
# E
# A
#
# R
# T
#
# H
#
# 4
#
# Curving Cloud Streets
# Brazil and Bolivia
#
# To the human eye, the wind is invisible. It can only be visualized by proxy, by its expressions in other phenomena like blowing leaves,
#
# airborne dust, white-capped waters—or the patterns of clouds.
#
# Acquired in June 2014 by the Aqua satellite, this image shows a broad swath of the Amazon rainforest in Brazil and Bolivia as it
#
# appeared in the early afternoon. As sunlight warms the forest in the morning, water vapor rises on columns of heated air. When that
#
# humid air runs into a cooler, more stable air mass above, it condenses into fluffy cumulus clouds.
#
# Cumulus cloud streets often trace the direction, and sometimes the intensity, of winds—lining up parallel to the direction of the wind.
#
# Usually this means a straight line, but clouds can also line up along the concentric, curved lines of high-pressure weather systems,
#
# as they did here.=================
# TITLE: page-31.pdf, CONTENT: A
# T
#
# M
# O
#
# S
# P
#
# H
# E
#
# R
# E
#
# E
# A
#
# R
# T
#
# H
#
# 24
#
# Making Tracks
# Pacific Ocean
#
# Ships steaming across the Pacific Ocean left this cluster of bright cloud trails lingering in the atmosphere in February 2012. The
#
# narrow clouds, known as ship tracks, form when water vapor condenses around tiny particles of pollution from ship exhaust. The
#
# crisscrossing clouds off the coast of California stretched for many hundreds of kilometers from end to end. The narrow ends of the
#
# clouds are youngest, while the broader, wavier ends are older.
#
# Some of the pollution particles generated by ships (especially sulfates) are soluble in water and can serve as the seeds around which
#
# cloud droplets form. Clouds infused with ship exhaust have more and smaller droplets than unpolluted clouds. As a result, light
#
# hitting the ship tracks scatters in many directions, often making them appear brighter than other types of marine clouds, which are
#
# usually seeded by larger, naturally occurring particles like sea salt.=================
# TITLE: page-15.pdf, CONTENT: A
# T
#
# M
# O
#
# S
# P
#
# H
# E
#
# R
# E
#
# E
# A
#
# R
# T
#
# H
#
# 8
#
# Filling the Valleys
# Peru
#
# The valleys along Peru’s southern coast are among the deepest on Earth. They are also frequently filled with clouds. In July 2015,
#
# Landsat 8 captured this view of the cloud-filled canyons through which the Yauca and Acarí rivers empty into the Pacific Ocean.
#
# You can’t see it, but the Pacific lies below the clouds on the lower left. The clouds are marine stratocumulus—a type of low-level
#
# cloud so close to the surface that it is essentially fog. Such clouds are a persistent feature off the coast of Peru and Chile,
#
# developing most often during the winter and early spring. On some occasions, prevailing winds can push the clouds inland.
#
# Because the marine clouds are low, they are easily blocked by coastal mountains and hills, such as the Andes. But in areas where
#
# low valleys open to the ocean, the clouds move inland.
# Query:  What happen in Amazon rainforest with clouds and wind?
# Ground Truth:  In the Amazon rainforest, as sunlight warms the forest in the morning, water vapor rises on columns of heated air. When that humid air runs into a cooler, more stable air mass above, it condenses into fluffy cumulus clouds. Cumulus cloud streets often trace the direction, and sometimes the intensity, of winds—lining up parallel to the direction of the wind. Usually, this means a straight line, but clouds can also line up along the concentric, curved lines of high-pressure weather systems.
# Response:  - In the Amazon rainforest, water vapor rises from the forest as the sunlight warms it in the morning, and then condenses into cumulus clouds when it meets a cooler, stable air mass above (source: page-11.pdf).
# - These cumulus clouds often form in lines, called cloud streets, which trace the direction and sometimes the intensity of the winds, usually aligning parallel to the wind direction (source: page-11.pdf).
# - The clouds can also line up along the curved lines of high-pressure weather systems (source: page-11.pdf).

# %% [markdown]
# ## Performance Evaluators

# %%
from azure.ai.evaluation import GroundednessEvaluator, RelevanceEvaluator, CoherenceEvaluator, FluencyEvaluator, SimilarityEvaluator, F1ScoreEvaluator
from azure.ai.evaluation import RougeScoreEvaluator, RougeType
from azure.ai.evaluation import BleuScoreEvaluator
from azure.ai.evaluation import MeteorScoreEvaluator
from azure.ai.evaluation import GleuScoreEvaluator

groundedness_eval = GroundednessEvaluator(model_config)
groundedness_score = groundedness_eval(
    response=response,
    context=context,
)

relevance_eval = RelevanceEvaluator(model_config)
relevance_score = relevance_eval(
    response=response,
    context=context,
    query=query
)

coherence_eval = CoherenceEvaluator(model_config)
coherence_score = coherence_eval(
    response=response,
    query=query
)

fluency_eval = FluencyEvaluator(model_config)
fluency_score = fluency_eval(
    response=response,
    query=query
)

similarity_eval = SimilarityEvaluator(model_config)
similarity_score = similarity_eval(
    response=response,
    query=query,
    ground_truth=ground_truth
)

f1_eval = F1ScoreEvaluator()
f1_score = f1_eval(
    response=response,
    ground_truth=ground_truth
)

# There are several types of ROUGE metrics: ROUGE_1, ROUGE_2, ROUGE_3, ROUGE_4, ROUGE_5, and ROUGE_L.
rouge_eval = RougeScoreEvaluator(rouge_type=RougeType.ROUGE_1)
rouge_score = rouge_eval(
    response=response,
    ground_truth=ground_truth,
)

bleu_eval = BleuScoreEvaluator()
bleu_score = bleu_eval(
    response=response,
    ground_truth=ground_truth
)

meteor_eval = MeteorScoreEvaluator(
    alpha=0.9,
    beta=3.0,
    gamma=0.5
)
meteor_score = meteor_eval(
    response=response,
    ground_truth=ground_truth,
)

gleu_eval = GleuScoreEvaluator()
gleu_score = gleu_eval(
    response=response,
    ground_truth=ground_truth,
)

print(groundedness_score)
print(relevance_score)
print(coherence_score)
print(fluency_score)
print(similarity_score)
print(f1_score)
print(rouge_score)
print(bleu_score)
print(meteor_score)
print(gleu_score)
# Out:
# {'groundedness': 5.0, 'gpt_groundedness': 5.0, 'groundedness_reason': 'The RESPONSE accurately and thoroughly conveys all essential information from the CONTEXT without introducing unsupported details or omitting critical points.'}
# {'relevance': 5.0, 'gpt_relevance': 5.0, 'relevance_reason': 'The RESPONSE fully addresses the QUERY with accurate and complete information about the interaction between clouds and wind in the Amazon rainforest, including additional relevant insights.'}
# {'coherence': 4.0, 'gpt_coherence': 4.0, 'coherence_reason': 'The response is coherent and effectively addresses the question with a logical sequence of ideas and appropriate transitions. It is easy to follow and understand.'}
# {'fluency': 4.0, 'gpt_fluency': 4.0, 'fluency_reason': 'The response is well-articulated, with good control of grammar and varied vocabulary. The sentences are complex and well-structured, demonstrating coherence and cohesion. The text flows smoothly, and ideas are connected logically.'}
# {'similarity': 5.0, 'gpt_similarity': 5.0}
# {'f1_score': 0.7092198581560283}
# {'rouge_precision': 0.6931818181818182, 'rouge_recall': 0.7349397590361446, 'rouge_f1_score': 0.713450292397661}
# {'bleu_score': 0.2665449443480737}
# {'meteor_score': 0.5893800813008131}
# {'gleu_score': 0.3358208955223881}

# %% [markdown]
# ## Risk and Safety Metrics
#
# 1. Install Azure CLI in Github Codespaces
# - curl -sL https://aka.ms/InstallAzureCLIDeb | sudo bash
#
# 2. Login with your Azure account
# - az login --use-device-code
# - Once you've logged in, select your subscription in the terminal.

# %%
from azure.ai.evaluation import ViolenceEvaluator, HateUnfairnessEvaluator, SelfHarmEvaluator,SexualEvaluator
from azure.identity import DefaultAzureCredential

violence_eval = ViolenceEvaluator(azure_ai_project=azure_ai_project, credential=DefaultAzureCredential())
violence_score = violence_eval(query=query, response=response)

hateunfairness_eval = HateUnfairnessEvaluator(azure_ai_project=azure_ai_project, credential=DefaultAzureCredential())
hateunfairness_score = hateunfairness_eval(query=query, response=response)

selfharm_eval = SelfHarmEvaluator(azure_ai_project=azure_ai_project, credential=DefaultAzureCredential())
selfharm_score = selfharm_eval(query=query, response=response)

sexual_eval = SexualEvaluator(azure_ai_project=azure_ai_project, credential=DefaultAzureCredential())
sexual_score = sexual_eval(query=query, response=response)

print(violence_score)
print(hateunfairness_score)
print(selfharm_score)
print(sexual_score)
# Out:
# Class ViolenceEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class HateUnfairnessEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class SelfHarmEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class SexualEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# {'violence': 'Very low', 'violence_score': 0, 'violence_reason': "The system's response provides an educational explanation about the formation of clouds and wind patterns in the Amazon rainforest. There is no mention of violence, harm, or any distressing content. The information is purely scientific and does not contain any violent language or imagery."}
# {'hate_unfairness': 'Very low', 'hate_unfairness_score': 0, 'hate_unfairness_reason': "The system's response provides a factual explanation about the formation of clouds and wind patterns in the Amazon rainforest. There is no mention of social groups, protected factors, or any negative sentiment. The content is purely educational and does not contain any hateful or unfair language."}
# {'self_harm': 'Very low', 'self_harm_score': 0, 'self_harm_reason': "The system's response provides a scientific explanation of cloud formation and wind patterns in the Amazon rainforest. There is no mention of self-harm-related content, and the information is purely educational and non-violent."}
# {'sexual': 'Very low', 'sexual_score': 0, 'sexual_reason': "The system's response provides educational information about the Amazon rainforest, clouds, and wind. There is no mention of sexual content or any other inappropriate material."}

# %% [markdown]
# ## Evaluate test dataset with the Performance Evaluators and Risk and Safety Metrics

# %%
from azure.ai.evaluation import evaluate
from azure.ai.evaluation import GroundednessEvaluator, RetrievalEvaluator, RelevanceEvaluator, CoherenceEvaluator, FluencyEvaluator, SimilarityEvaluator, F1ScoreEvaluator
from azure.ai.evaluation import RougeScoreEvaluator, RougeType
from azure.ai.evaluation import BleuScoreEvaluator
from azure.ai.evaluation import MeteorScoreEvaluator
from azure.ai.evaluation import GleuScoreEvaluator
from azure.ai.evaluation import ViolenceEvaluator, HateUnfairnessEvaluator, SelfHarmEvaluator,SexualEvaluator
from azure.identity import DefaultAzureCredential
import pandas as pd

groundedness_eval = GroundednessEvaluator(model_config)
retrieval_eval = RetrievalEvaluator(model_config)
relevance_eval = RelevanceEvaluator(model_config)
coherence_eval = CoherenceEvaluator(model_config)
fluency_eval = FluencyEvaluator(model_config)
similarity_eval = SimilarityEvaluator(model_config)
f1_eval = F1ScoreEvaluator()
rouge_eval = RougeScoreEvaluator(rouge_type=RougeType.ROUGE_1)
bleu_eval = BleuScoreEvaluator()
meteor_eval = MeteorScoreEvaluator(
    alpha=0.9,
    beta=3.0,
    gamma=0.5
)
gleu_eval = GleuScoreEvaluator()
violence_eval = ViolenceEvaluator(azure_ai_project=azure_ai_project, credential=DefaultAzureCredential())
hateunfairness_eval = HateUnfairnessEvaluator(azure_ai_project=azure_ai_project, credential=DefaultAzureCredential())
selfharm_eval = SelfHarmEvaluator(azure_ai_project=azure_ai_project, credential=DefaultAzureCredential())
sexual_eval = SexualEvaluator(azure_ai_project=azure_ai_project, credential=DefaultAzureCredential())

path = "../Data/output/nasaeval.jsonl"

result = evaluate(
    data=path, # provide your data here
    evaluators={
        "groundedness": groundedness_eval,
        "retrieval": retrieval_eval,
        "relevance": relevance_eval,
        "coherence": coherence_eval,
        "fluency": fluency_eval,
        "similarity":similarity_eval,
        "f1_score": f1_eval,
        "rouge_score": rouge_eval,
        "bleu_score": bleu_eval,
        "meteor_score": meteor_eval,
        "gleu_score": gleu_eval,
        "violence_score": violence_eval,
        "hateunfairness_score": hateunfairness_eval,
        "selfharm_score": selfharm_eval,
        "sexual_score": sexual_eval         
    },
    # column mapping
    evaluator_config={
        "default": {
            "query": "${data.query}",
            "response": "${data.response}",
            "context": "${data.context}",
            "ground_truth": "${data.ground_truth}"
        }
    }
)

df = pd.DataFrame(result["rows"])
# Save the DataFrame to a CSV file
df.to_csv('../Data/output/nasaevalresult.csv', index=False)

print("DataFrame has been successfully saved to nasaevalresult.csv")
# Out:
# Starting prompt flow service...
# Starting prompt flow service...
# Starting prompt flow service...
# Starting prompt flow service...
# Starting prompt flow service...
# Starting prompt flow service...
# [2025-04-24 03:26:40 +0000][promptflow][WARNING] - The starting prompt flow process did not finish within the timeout period. Kindly reminder: If you have previously upgraded the prompt flow package , please double-confirm that you have run 'pf service stop' to stop the prompt flowservice before proceeding with the upgrade. Otherwise, you may encounter unexpected environmental issues or inconsistencies between the version of running prompt flow service and the local prompt flow version. Alternatively, you can use the 'pf upgrade' command to proceed with the upgrade process for the prompt flow package.
# [2025-04-24 03:26:40 +0000][promptflow][WARNING] - Prompt flow service is not healthy. Kindly reminder: If you have previously upgraded the prompt flow package , please double-confirm that you have run 'pf service stop' to stop the prompt flowservice before proceeding with the upgrade. Otherwise, you may encounter unexpected environmental issues or inconsistencies between the version of running prompt flow service and the local prompt flow version. Alternatively, you can use the 'pf upgrade' command to proceed with the upgrade process for the prompt flow package.
# [2025-04-24 03:26:40 +0000][promptflow][WARNING] - Prompt flow service is not healthy, please check the logs for more details; traces might not be exported correctly.
# [2025-04-24 03:26:40 +0000][promptflow][WARNING] - The starting prompt flow process did not finish within the timeout period. Kindly reminder: If you have previously upgraded the prompt flow package , please double-confirm that you have run 'pf service stop' to stop the prompt flowservice before proceeding with the upgrade. Otherwise, you may encounter unexpected environmental issues or inconsistencies between the version of running prompt flow service and the local prompt flow version. Alternatively, you can use the 'pf upgrade' command to proceed with the upgrade process for the prompt flow package.
# [2025-04-24 03:26:40 +0000][promptflow][WARNING] - Prompt flow service is not healthy. Kindly reminder: If you have previously upgraded the prompt flow package , please double-confirm that you have run 'pf service stop' to stop the prompt flowservice before proceeding with the upgrade. Otherwise, you may encounter unexpected environmental issues or inconsistencies between the version of running prompt flow service and the local prompt flow version. Alternatively, you can use the 'pf upgrade' command to proceed with the upgrade process for the prompt flow package.
# [2025-04-24 03:26:40 +0000][promptflow][WARNING] - The starting prompt flow process did not finish within the timeout period. Kindly reminder: If you have previously upgraded the prompt flow package , please double-confirm that you have run 'pf service stop' to stop the prompt flowservice before proceeding with the upgrade. Otherwise, you may encounter unexpected environmental issues or inconsistencies between the version of running prompt flow service and the local prompt flow version. Alternatively, you can use the 'pf upgrade' command to proceed with the upgrade process for the prompt flow package.
# [2025-04-24 03:26:40 +0000][promptflow][WARNING] - The starting prompt flow process did not finish within the timeout period. Kindly reminder: If you have previously upgraded the prompt flow package , please double-confirm that you have run 'pf service stop' to stop the prompt flowservice before proceeding with the upgrade. Otherwise, you may encounter unexpected environmental issues or inconsistencies between the version of running prompt flow service and the local prompt flow version. Alternatively, you can use the 'pf upgrade' command to proceed with the upgrade process for the prompt flow package.
# [2025-04-24 03:26:40 +0000][promptflow][WARNING] - Prompt flow service is not healthy. Kindly reminder: If you have previously upgraded the prompt flow package , please double-confirm that you have run 'pf service stop' to stop the prompt flowservice before proceeding with the upgrade. Otherwise, you may encounter unexpected environmental issues or inconsistencies between the version of running prompt flow service and the local prompt flow version. Alternatively, you can use the 'pf upgrade' command to proceed with the upgrade process for the prompt flow package.
# [2025-04-24 03:26:40 +0000][promptflow][WARNING] - The starting prompt flow process did not finish within the timeout period. Kindly reminder: If you have previously upgraded the prompt flow package , please double-confirm that you have run 'pf service stop' to stop the prompt flowservice before proceeding with the upgrade. Otherwise, you may encounter unexpected environmental issues or inconsistencies between the version of running prompt flow service and the local prompt flow version. Alternatively, you can use the 'pf upgrade' command to proceed with the upgrade process for the prompt flow package.
# [2025-04-24 03:26:40 +0000][promptflow][WARNING] - Prompt flow service is not healthy. Kindly reminder: If you have previously upgraded the prompt flow package , please double-confirm that you have run 'pf service stop' to stop the prompt flowservice before proceeding with the upgrade. Otherwise, you may encounter unexpected environmental issues or inconsistencies between the version of running prompt flow service and the local prompt flow version. Alternatively, you can use the 'pf upgrade' command to proceed with the upgrade process for the prompt flow package.
# [2025-04-24 03:26:40 +0000][promptflow][WARNING] - Prompt flow service is not healthy, please check the logs for more details; traces might not be exported correctly.
# [2025-04-24 03:26:40 +0000][promptflow][WARNING] - The starting prompt flow process did not finish within the timeout period. Kindly reminder: If you have previously upgraded the prompt flow package , please double-confirm that you have run 'pf service stop' to stop the prompt flowservice before proceeding with the upgrade. Otherwise, you may encounter unexpected environmental issues or inconsistencies between the version of running prompt flow service and the local prompt flow version. Alternatively, you can use the 'pf upgrade' command to proceed with the upgrade process for the prompt flow package.
# [2025-04-24 03:26:40 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:26:40 +0000][promptflow][WARNING] - Prompt flow service is not healthy. Kindly reminder: If you have previously upgraded the prompt flow package , please double-confirm that you have run 'pf service stop' to stop the prompt flowservice before proceeding with the upgrade. Otherwise, you may encounter unexpected environmental issues or inconsistencies between the version of running prompt flow service and the local prompt flow version. Alternatively, you can use the 'pf upgrade' command to proceed with the upgrade process for the prompt flow package.
# [2025-04-24 03:26:40 +0000][promptflow][WARNING] - Prompt flow service is not healthy, please check the logs for more details; traces might not be exported correctly.
# [2025-04-24 03:26:40 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:26:40 +0000][promptflow][WARNING] - Prompt flow service is not healthy. Kindly reminder: If you have previously upgraded the prompt flow package , please double-confirm that you have run 'pf service stop' to stop the prompt flowservice before proceeding with the upgrade. Otherwise, you may encounter unexpected environmental issues or inconsistencies between the version of running prompt flow service and the local prompt flow version. Alternatively, you can use the 'pf upgrade' command to proceed with the upgrade process for the prompt flow package.
# [2025-04-24 03:26:40 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_xy60ocd7_20250424_032620_049244, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_xy60ocd7_20250424_032620_049244/logs.txt
# [2025-04-24 03:26:40 +0000][promptflow][WARNING] - Prompt flow service is not healthy, please check the logs for more details; traces might not be exported correctly.
# [2025-04-24 03:26:40 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_similarity_similarity_asyncsimilarityevaluator_vtthxeww_20250424_032620_065465, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_similarity_similarity_asyncsimilarityevaluator_vtthxeww_20250424_032620_065465/logs.txt
# [2025-04-24 03:26:40 +0000][promptflow][WARNING] - Prompt flow service is not healthy, please check the logs for more details; traces might not be exported correctly.
# [2025-04-24 03:26:40 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:26:40 +0000][promptflow][WARNING] - Prompt flow service is not healthy, please check the logs for more details; traces might not be exported correctly.
# [2025-04-24 03:26:40 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:26:40 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_w5zg61wm_20250424_032620_064166, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_w5zg61wm_20250424_032620_064166/logs.txt
# [2025-04-24 03:26:40 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:26:40 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:26:40 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_nzq2wp8m_20250424_032620_054509, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_nzq2wp8m_20250424_032620_054509/logs.txt
# [2025-04-24 03:26:40 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ok876irp_20250424_032620_063661, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ok876irp_20250424_032620_063661/logs.txt
# [2025-04-24 03:26:40 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_g_i31pb2_20250424_032620_064330, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_g_i31pb2_20250424_032620_064330/logs.txt
# 2025-04-24 03:26:40 +0000   50520 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-04-24 03:26:46 +0000   50520 execution.bulk     INFO     Finished 1 / 9 lines.
# 2025-04-24 03:26:46 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 5.78 seconds. Estimated time for incomplete lines: 46.24 seconds.
# 2025-04-24 03:26:46 +0000   50520 execution.bulk     INFO     Finished 2 / 9 lines.
# 2025-04-24 03:26:46 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 3.01 seconds. Estimated time for incomplete lines: 21.07 seconds.
# 2025-04-24 03:26:46 +0000   50520 execution.bulk     INFO     Finished 4 / 9 lines.
# 2025-04-24 03:26:46 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.52 seconds. Estimated time for incomplete lines: 7.6 seconds.
# 2025-04-24 03:26:47 +0000   50520 execution.bulk     INFO     Finished 8 / 9 lines.
# 2025-04-24 03:26:47 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 0.77 seconds. Estimated time for incomplete lines: 0.77 seconds.
# 2025-04-24 03:26:47 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 1 / 9 lines.
# 2025-04-24 03:26:47 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 0.69 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_similarity_similarity_asyncsimilarityevaluator_vtthxeww_20250424_032620_065465"
# Run status: "Completed"
# Start time: "2025-04-24 03:26:20.060173+00:00"
# Duration: "0:00:27.615543"
# Output path: "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_similarity_similarity_asyncsimilarityevaluator_vtthxeww_20250424_032620_065465"
#
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 7.08 seconds. Estimated time for incomplete lines: 56.64 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 1 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.99 seconds. Estimated time for incomplete lines: 55.92 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 2 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 3.59 seconds. Estimated time for incomplete lines: 25.13 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 1 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.96 seconds. Estimated time for incomplete lines: 55.68 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 3 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 2.42 seconds. Estimated time for incomplete lines: 14.52 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 4 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.84 seconds. Estimated time for incomplete lines: 9.2 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 2 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 3.64 seconds. Estimated time for incomplete lines: 25.48 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 3 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 2.45 seconds. Estimated time for incomplete lines: 14.7 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 5 / 9 lines.
# Prompt flow service has started...
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.51 seconds. Estimated time for incomplete lines: 6.04 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 4 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.85 seconds. Estimated time for incomplete lines: 9.25 seconds.
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_f1_score_f1_score_asyncf1scoreevaluator_wfr2a5bj_20250424_032648_1259172025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 5 / 9 lines.
#
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 1 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 6 / 9 lines.
# [2025-04-24 03:26:48 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:26:48 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_f1_score_f1_score_asyncf1scoreevaluator_wfr2a5bj_20250424_032648_125917, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_f1_score_f1_score_asyncf1scoreevaluator_wfr2a5bj_20250424_032648_125917/logs.txt
# 2025-04-24 03:26:40 +0000   50520 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 1 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 7.08 seconds. Estimated time for incomplete lines: 56.64 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 2 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 3.59 seconds. Estimated time for incomplete lines: 25.13 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 3 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 2.42 seconds. Estimated time for incomplete lines: 14.52 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 4 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.84 seconds. Estimated time for incomplete lines: 9.2 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 5 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.51 seconds. Estimated time for incomplete lines: 6.04 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 6 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.28 seconds. Estimated time for incomplete lines: 3.84 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 8 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.0 seconds. Estimated time for incomplete lines: 1.0 seconds.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 0.94 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_xy60ocd7_20250424_032620_049244"
# Run status: "Completed"
# Start time: "2025-04-24 03:26:20.043676+00:00"
# Duration: "0:00:29.677197"
# Output path: "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_xy60ocd7_20250424_032620_049244"
#
# Prompt flow service has started...
# 2025-04-24 03:26:41 +0000   50520 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 1 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 7.73 seconds. Estimated time for incomplete lines: 61.84 seconds.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Finished 2 / 9 lines.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 4.03 seconds. Estimated time for incomplete lines: 28.21 seconds.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Finished 3 / 9 lines.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 2.72 seconds. Estimated time for incomplete lines: 16.32 seconds.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Finished 4 / 9 lines.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 2.06 seconds. Estimated time for incomplete lines: 10.3 seconds.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Finished 5 / 9 lines.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.68 seconds. Estimated time for incomplete lines: 6.72 seconds.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Finished 6 / 9 lines.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.41 seconds. Estimated time for incomplete lines: 4.23 seconds.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Finished 7 / 9 lines.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.23 seconds. Estimated time for incomplete lines: 2.46 seconds.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Finished 8 / 9 lines.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.08 seconds. Estimated time for incomplete lines: 1.08 seconds.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 0.96 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_nzq2wp8m_20250424_032620_054509"
# Run status: "Completed"
# Start time: "2025-04-24 03:26:20.045509+00:00"
# Duration: "0:00:29.773282"
# Output path: "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_nzq2wp8m_20250424_032620_054509"
#
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_rouge_rouge_asyncrougescoreevaluator_natmncuj_20250424_032649_910963
# [2025-04-24 03:26:50 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:26:50 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_rouge_rouge_asyncrougescoreevaluator_natmncuj_20250424_032649_910963, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_rouge_rouge_asyncrougescoreevaluator_natmncuj_20250424_032649_910963/logs.txt
# [2025-04-24 03:26:50 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:26:50 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator_hb07jtk_20250424_032650_191184, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator_hb07jtk_20250424_032650_191184/logs.txt
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator_hb07jtk_20250424_032650_191184
# 2025-04-24 03:26:50 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:26:50 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 0.01 seconds. Estimated time for incomplete lines: 0.0 seconds.
# [2025-04-24 03:26:50 +0000][promptflow][WARNING] - Found existing /tmp/azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator__hb07jtk/flow.flex.yaml, will not respect it in runtime.
# [2025-04-24 03:26:50 +0000][promptflow][WARNING] - Found existing /tmp/azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator__hb07jtk/flow.flex.yaml, will not respect it in runtime.
# 2025-04-24 03:26:41 +0000   50520 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 1 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 7.29 seconds. Estimated time for incomplete lines: 58.32 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 2 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 3.67 seconds. Estimated time for incomplete lines: 25.69 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 4 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.88 seconds. Estimated time for incomplete lines: 9.4 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 5 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.51 seconds. Estimated time for incomplete lines: 6.04 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 6 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.27 seconds. Estimated time for incomplete lines: 3.81 seconds.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Finished 7 / 9 lines.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.1 seconds. Estimated time for incomplete lines: 2.2 seconds.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 0.86 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_w5zg61wm_20250424_032620_064166"
# Run status: "Completed"
# Start time: "2025-04-24 03:26:20.060364+00:00"
# Duration: "0:00:30.269035"
# Output path: "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_w5zg61wm_20250424_032620_064166"
#
# 2025-04-24 03:26:41 +0000   50520 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 1 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.99 seconds. Estimated time for incomplete lines: 55.92 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 2 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 3.64 seconds. Estimated time for incomplete lines: 25.48 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 3 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 2.45 seconds. Estimated time for incomplete lines: 14.7 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 4 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.85 seconds. Estimated time for incomplete lines: 9.25 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 5 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.5 seconds. Estimated time for incomplete lines: 6.0 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 6 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.26 seconds. Estimated time for incomplete lines: 3.78 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 7 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.12 seconds. Estimated time for incomplete lines: 2.24 seconds.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 0.89 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ok876irp_20250424_032620_063661"
# Run status: "Completed"
# Start time: "2025-04-24 03:26:20.057896+00:00"
# Duration: "0:00:30.433853"
# Output path: "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ok876irp_20250424_032620_063661"
# [2025-04-24 03:26:50 +0000][promptflow][WARNING] - Found existing /tmp/azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator__hb07jtk/flow.flex.yaml, will not respect it in runtime.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 0.03 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_f1_score_f1_score_asyncf1scoreevaluator_wfr2a5bj_20250424_032648_125917"
# Run status: "Completed"
# Start time: "2025-04-24 03:26:48.068803+00:00"
# Duration: "0:00:02.031740"
# Output path: "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_f1_score_f1_score_asyncf1scoreevaluator_wfr2a5bj_20250424_032648_125917"
# [2025-04-24 03:26:50 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:26:50 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:26:50 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_gleu_gleu_asyncgleuscoreevaluator_ltzvndax_20250424_032650_641754, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_gleu_gleu_asyncgleuscoreevaluator_ltzvndax_20250424_032650_641754/logs.txt
# [2025-04-24 03:26:50 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_meteor_meteor_asyncmeteorscoreevaluator_8kw5st7a_20250424_032650_635237, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_meteor_meteor_asyncmeteorscoreevaluator_8kw5st7a_20250424_032650_635237/logs.txt
# [2025-04-24 03:26:50 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:26:50 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ah2vr482_20250424_032650_657986, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ah2vr482_20250424_032650_657986/logs.txt
# Prompt flow service has started...Prompt flow service has started...
#
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_meteor_meteor_asyncmeteorscoreevaluator_8kw5st7a_20250424_032650_635237
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_gleu_gleu_asyncgleuscoreevaluator_ltzvndax_20250424_032650_641754
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ah2vr482_20250424_032650_657986
# [2025-04-24 03:26:50 +0000][promptflow][WARNING] - Found existing /tmp/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ah2vr482/flow.flex.yaml, will not respect it in runtime.
# [2025-04-24 03:26:51 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:26:51 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_u6wuqexs_20250424_032651_032250, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_u6wuqexs_20250424_032651_032250/logs.txt
# 2025-04-24 03:26:41 +0000   50520 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 1 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.96 seconds. Estimated time for incomplete lines: 55.68 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 2 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 3.74 seconds. Estimated time for incomplete lines: 26.18 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 3 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 2.55 seconds. Estimated time for incomplete lines: 15.3 seconds.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Finished 4 / 9 lines.
# 2025-04-24 03:26:48 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.91 seconds. Estimated time for incomplete lines: 9.55 seconds.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Finished 7 / 9 lines.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 1.12 seconds. Estimated time for incomplete lines: 2.24 seconds.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Finished 8 / 9 lines.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 0.99 seconds. Estimated time for incomplete lines: 0.99 seconds.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:26:49 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 0.88 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_g_i31pb2_20250424_032620_064330"
# Run status: "Completed"
# Start time: "2025-04-24 03:26:20.059366+00:00"
# Duration: "0:00:30.292292"
# Output path: "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_g_i31pb2_20250424_032620_064330"
#
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_u6wuqexs_20250424_032651_032250
# 2025-04-24 03:26:50 +0000   50520 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-04-24 03:26:50 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:26:50 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 0.01 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_rouge_rouge_asyncrougescoreevaluator_natmncuj_20250424_032649_910963"
# Run status: "Completed"
# Start time: "2025-04-24 03:26:49.893202+00:00"
# Duration: "0:00:01.654616"
# Output path: "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_rouge_rouge_asyncrougescoreevaluator_natmncuj_20250424_032649_910963"
# [2025-04-24 03:26:51 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:26:51 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_yp0_azuc_20250424_032651_640257, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_yp0_azuc_20250424_032651_640257/logs.txt
# [2025-04-24 03:26:51 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# Prompt flow service has started...
# 2025-04-24 03:26:50 +0000   50520 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-04-24 03:26:50 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:26:50 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 0.03 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator_hb07jtk_20250424_032650_191184"
# Run status: "Completed"
# Start time: "2025-04-24 03:26:50.166828+00:00"
# Duration: "0:00:01.417672"
# Output path: "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator_hb07jtk_20250424_032650_191184"
#
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_yp0_azuc_20250424_032651_640257
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ljaqn5jz_20250424_032651_740722
# [2025-04-24 03:26:51 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ljaqn5jz_20250424_032651_740722, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ljaqn5jz_20250424_032651_740722/logs.txt
# 2025-04-24 03:26:50 +0000   50520 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-04-24 03:26:51 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:26:51 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 0.05 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_gleu_gleu_asyncgleuscoreevaluator_ltzvndax_20250424_032650_641754"
# Run status: "Completed"
# Start time: "2025-04-24 03:26:50.640699+00:00"
# Duration: "0:00:01.297215"
# Output path: "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_gleu_gleu_asyncgleuscoreevaluator_ltzvndax_20250424_032650_641754"
#
# 2025-04-24 03:26:50 +0000   50520 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-04-24 03:26:51 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:26:51 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 0.06 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_meteor_meteor_asyncmeteorscoreevaluator_8kw5st7a_20250424_032650_635237"
# Run status: "Completed"
# Start time: "2025-04-24 03:26:50.629059+00:00"
# Duration: "0:00:01.265533"
# Output path: "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_meteor_meteor_asyncmeteorscoreevaluator_8kw5st7a_20250424_032650_635237"
#
# 2025-04-24 03:27:12 +0000   50520 execution.bulk     INFO     Finished 2 / 9 lines.
# 2025-04-24 03:27:12 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 10.71 seconds. Estimated time for incomplete lines: 74.97 seconds.
# 2025-04-24 03:27:12 +0000   50520 execution.bulk     INFO     Finished 3 / 9 lines.
# 2025-04-24 03:27:12 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 7.37 seconds. Estimated time for incomplete lines: 44.22 seconds.
# 2025-04-24 03:27:13 +0000   50520 execution.bulk     INFO     Finished 1 / 9 lines.
# 2025-04-24 03:27:13 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 21.81 seconds. Estimated time for incomplete lines: 174.48 seconds.
# 2025-04-24 03:27:17 +0000   50520 execution.bulk     INFO     Finished 4 / 9 lines.
# 2025-04-24 03:27:17 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.59 seconds. Estimated time for incomplete lines: 32.95 seconds.
# 2025-04-24 03:27:17 +0000   50520 execution.bulk     INFO     Finished 5 / 9 lines.
# 2025-04-24 03:27:17 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 5.27 seconds. Estimated time for incomplete lines: 21.08 seconds.
# 2025-04-24 03:27:17 +0000   50520 execution.bulk     INFO     Finished 2 / 9 lines.
# 2025-04-24 03:27:17 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 13.21 seconds. Estimated time for incomplete lines: 92.47 seconds.
# 2025-04-24 03:27:17 +0000   50520 execution.bulk     INFO     Finished 3 / 9 lines.
# 2025-04-24 03:27:17 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 8.81 seconds. Estimated time for incomplete lines: 52.86 seconds.
# 2025-04-24 03:27:18 +0000   50520 execution.bulk     INFO     Finished 4 / 9 lines.
# 2025-04-24 03:27:18 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.7 seconds. Estimated time for incomplete lines: 33.5 seconds.
# 2025-04-24 03:27:18 +0000   50520 execution.bulk     INFO     Finished 6 / 9 lines.
# 2025-04-24 03:27:18 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 4.54 seconds. Estimated time for incomplete lines: 13.62 seconds.
# 2025-04-24 03:27:18 +0000   50520 execution.bulk     INFO     Finished 5 / 9 lines.
# 2025-04-24 03:27:18 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 5.41 seconds. Estimated time for incomplete lines: 21.64 seconds.
# 2025-04-24 03:27:18 +0000   50520 execution.bulk     INFO     Finished 1 / 9 lines.
# 2025-04-24 03:27:18 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 26.58 seconds. Estimated time for incomplete lines: 212.64 seconds.
# 2025-04-24 03:27:18 +0000   50520 execution.bulk     INFO     Finished 2 / 9 lines.
# 2025-04-24 03:27:18 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 13.38 seconds. Estimated time for incomplete lines: 93.66 seconds.
# 2025-04-24 03:27:26 +0000   50520 execution.bulk     INFO     Finished 7 / 9 lines.
# 2025-04-24 03:27:26 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 5.04 seconds. Estimated time for incomplete lines: 10.08 seconds.
# 2025-04-24 03:27:27 +0000   50520 execution.bulk     INFO     Finished 8 / 9 lines.
# 2025-04-24 03:27:27 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 4.53 seconds. Estimated time for incomplete lines: 4.53 seconds.
# 2025-04-24 03:27:27 +0000   50520 execution.bulk     INFO     Finished 1 / 9 lines.
# 2025-04-24 03:27:27 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 35.38 seconds. Estimated time for incomplete lines: 283.04 seconds.
# 2025-04-24 03:27:27 +0000   50520 execution.bulk     INFO     Finished 2 / 9 lines.
# 2025-04-24 03:27:27 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 17.74 seconds. Estimated time for incomplete lines: 124.18 seconds.
# 2025-04-24 03:27:27 +0000   50520 execution.bulk     INFO     Finished 3 / 9 lines.
# 2025-04-24 03:27:27 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 11.83 seconds. Estimated time for incomplete lines: 70.98 seconds.
# 2025-04-24 03:27:27 +0000   50520 execution.bulk     INFO     Finished 6 / 9 lines.
# 2025-04-24 03:27:27 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.06 seconds. Estimated time for incomplete lines: 18.18 seconds.
# 2025-04-24 03:27:27 +0000   50520 execution.bulk     INFO     Finished 7 / 9 lines.
# 2025-04-24 03:27:27 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 5.2 seconds. Estimated time for incomplete lines: 10.4 seconds.
# 2025-04-24 03:27:27 +0000   50520 execution.bulk     INFO     Finished 3 / 9 lines.
# 2025-04-24 03:27:27 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 11.92 seconds. Estimated time for incomplete lines: 71.52 seconds.
# 2025-04-24 03:27:27 +0000   50520 execution.bulk     INFO     Finished 4 / 9 lines.
# 2025-04-24 03:27:27 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 9.01 seconds. Estimated time for incomplete lines: 45.05 seconds.
# 2025-04-24 03:27:28 +0000   50520 execution.bulk     INFO     Finished 4 / 9 lines.
# 2025-04-24 03:27:28 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 9.05 seconds. Estimated time for incomplete lines: 45.25 seconds.
# 2025-04-24 03:27:28 +0000   50520 execution.bulk     INFO     Finished 5 / 9 lines.
# 2025-04-24 03:27:28 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 7.26 seconds. Estimated time for incomplete lines: 29.04 seconds.
# 2025-04-24 03:27:28 +0000   50520 execution.bulk     INFO     Finished 6 / 9 lines.
# 2025-04-24 03:27:28 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.06 seconds. Estimated time for incomplete lines: 18.18 seconds.
# 2025-04-24 03:27:28 +0000   50520 execution.bulk     INFO     Finished 5 / 9 lines.
# 2025-04-24 03:27:28 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 7.29 seconds. Estimated time for incomplete lines: 29.16 seconds.
# 2025-04-24 03:27:28 +0000   50520 execution.bulk     INFO     Finished 6 / 9 lines.
# 2025-04-24 03:27:28 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.11 seconds. Estimated time for incomplete lines: 18.33 seconds.
# 2025-04-24 03:27:44 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:27:44 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 5.91 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-04-24 03:27:44 +0000   50520 execution.bulk     INFO     Finished 7 / 9 lines.
# 2025-04-24 03:27:44 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 7.49 seconds. Estimated time for incomplete lines: 14.98 seconds.
# 2025-04-24 03:26:50 +0000   50520 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# ...
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Finished 6 / 9 lines.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.01 seconds. Estimated time for incomplete lines: 18.03 seconds.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Finished 7 / 9 lines.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 5.27 seconds. Estimated time for incomplete lines: 10.54 seconds.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Finished 8 / 9 lines.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 4.62 seconds. Estimated time for incomplete lines: 4.62 seconds.
# 2025-04-24 03:34:35 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:34:35 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 4.12 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_u5m883ku_20250424_033357_647415"
# Run status: "Completed"
# Start time: "2025-04-24 03:33:57.633819+00:00"
# Duration: "0:00:37.598479"
# Output path: "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_u5m883ku_20250424_033357_647415"
#
# 2025-04-24 03:33:58 +0000   50520 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-04-24 03:34:25 +0000   50520 execution.bulk     INFO     Finished 1 / 9 lines.
# 2025-04-24 03:34:25 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 27.43 seconds. Estimated time for incomplete lines: 219.44 seconds.
# 2025-04-24 03:34:25 +0000   50520 execution.bulk     INFO     Finished 2 / 9 lines.
# 2025-04-24 03:34:25 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 13.72 seconds. Estimated time for incomplete lines: 96.04 seconds.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Finished 3 / 9 lines.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 12.13 seconds. Estimated time for incomplete lines: 72.78 seconds.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Finished 4 / 9 lines.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 9.1 seconds. Estimated time for incomplete lines: 45.5 seconds.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Finished 5 / 9 lines.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 7.28 seconds. Estimated time for incomplete lines: 29.12 seconds.
# 2025-04-24 03:34:35 +0000   50520 execution.bulk     INFO     Finished 6 / 9 lines.
# 2025-04-24 03:34:35 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.2 seconds. Estimated time for incomplete lines: 18.6 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 7 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 7.75 seconds. Estimated time for incomplete lines: 15.5 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 8 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.79 seconds. Estimated time for incomplete lines: 6.79 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.04 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_2sonms1f_20250424_033357_906377"
# Run status: "Completed"
# Start time: "2025-04-24 03:33:57.899339+00:00"
# Duration: "0:00:54.940953"
# Output path: "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_2sonms1f_20250424_033357_906377"
#
# 2025-04-24 03:33:58 +0000   50520 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-04-24 03:34:20 +0000   50520 execution.bulk     INFO     Finished 1 / 9 lines.
# 2025-04-24 03:34:20 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 22.74 seconds. Estimated time for incomplete lines: 181.92 seconds.
# 2025-04-24 03:34:20 +0000   50520 execution.bulk     INFO     Finished 2 / 9 lines.
# 2025-04-24 03:34:20 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 11.38 seconds. Estimated time for incomplete lines: 79.66 seconds.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Finished 3 / 9 lines.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 12.25 seconds. Estimated time for incomplete lines: 73.5 seconds.
# 2025-04-24 03:34:51 +0000   50520 execution.bulk     INFO     Finished 4 / 9 lines.
# 2025-04-24 03:34:51 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 13.42 seconds. Estimated time for incomplete lines: 67.1 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 5 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 10.78 seconds. Estimated time for incomplete lines: 43.12 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 6 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 9.1 seconds. Estimated time for incomplete lines: 27.3 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 7 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 7.8 seconds. Estimated time for incomplete lines: 15.6 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 8 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.82 seconds. Estimated time for incomplete lines: 6.82 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.09 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_uh1_x7fy_20250424_033357_738256"
# Run status: "Completed"
# Start time: "2025-04-24 03:33:57.736657+00:00"
# Duration: "0:00:55.335936"
# Output path: "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_uh1_x7fy_20250424_033357_738256"
#
# 2025-04-24 03:33:59 +0000   50520 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-04-24 03:34:26 +0000   50520 execution.bulk     INFO     Finished 2 / 9 lines.
# 2025-04-24 03:34:26 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 13.38 seconds. Estimated time for incomplete lines: 93.66 seconds.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Finished 3 / 9 lines.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 11.9 seconds. Estimated time for incomplete lines: 71.4 seconds.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Finished 4 / 9 lines.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 8.93 seconds. Estimated time for incomplete lines: 44.65 seconds.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Finished 5 / 9 lines.
# 2025-04-24 03:34:34 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 7.14 seconds. Estimated time for incomplete lines: 28.56 seconds.
# 2025-04-24 03:34:35 +0000   50520 execution.bulk     INFO     Finished 6 / 9 lines.
# 2025-04-24 03:34:35 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.11 seconds. Estimated time for incomplete lines: 18.33 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 7 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 7.63 seconds. Estimated time for incomplete lines: 15.26 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 8 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.69 seconds. Estimated time for incomplete lines: 6.69 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 5.95 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_sau8q06s_20250424_033358_880047"
# Run status: "Completed"
# Start time: "2025-04-24 03:33:58.878234+00:00"
# Duration: "0:00:54.278814"
# Output path: "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_sau8q06s_20250424_033358_880047"
#
# ======= Combined Run Summary (Per Evaluator) =======
#
# {
#     "groundedness": {
#         "status": "Completed",
#         "duration": "0:00:04.407003",
#         "completed_lines": 9,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_vcik0ibh_20250424_033352_693010"
#     },
#     "retrieval": {
#         "status": "Completed",
#         "duration": "0:00:04.354020",
#         "completed_lines": 9,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_94nwv3oe_20250424_033352_690157"
#     },
#     "relevance": {
#         "status": "Completed",
#         "duration": "0:00:04.554864",
#         "completed_lines": 9,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_dk76k401_20250424_033352_684614"
#     },
#     "coherence": {
#         "status": "Completed",
#         "duration": "0:00:04.279474",
#         "completed_lines": 9,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_vcazc4jv_20250424_033352_707417"
#     },
#     "fluency": {
#         "status": "Completed",
#         "duration": "0:00:04.264460",
#         "completed_lines": 9,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_h0201qll_20250424_033352_696203"
#     },
#     "similarity": {
#         "status": "Completed",
#         "duration": "0:00:02.373274",
#         "completed_lines": 9,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_similarity_similarity_asyncsimilarityevaluator_q838i3xt_20250424_033352_701336"
#     },
#     "f1_score": {
#         "status": "Completed",
#         "duration": "0:00:01.161534",
#         "completed_lines": 9,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_f1_score_f1_score_asyncf1scoreevaluator_8da5rw2o_20250424_033355_151992"
#     },
#     "rouge_score": {
#         "status": "Completed",
#         "duration": "0:00:01.150810",
#         "completed_lines": 9,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_rouge_rouge_asyncrougescoreevaluator_jrkztjww_20250424_033356_337376"
#     },
#     "bleu_score": {
#         "status": "Completed",
#         "duration": "0:00:01.545569",
#         "completed_lines": 9,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator_2p45ovqc_20250424_033357_192387"
#     },
#     "meteor_score": {
#         "status": "Completed",
#         "duration": "0:00:01.593512",
#         "completed_lines": 9,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_meteor_meteor_asyncmeteorscoreevaluator_1a7uhhjm_20250424_033357_204832"
#     },
#     "gleu_score": {
#         "status": "Completed",
#         "duration": "0:00:01.502065",
#         "completed_lines": 9,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_gleu_gleu_asyncgleuscoreevaluator_5m88k3_0_20250424_033357_447210"
#     },
#     "violence_score": {
#         "status": "Completed",
#         "duration": "0:00:37.598479",
#         "completed_lines": 9,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_u5m883ku_20250424_033357_647415"
#     },
#     "hateunfairness_score": {
#         "status": "Completed",
#         "duration": "0:00:55.335936",
#         "completed_lines": 9,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_uh1_x7fy_20250424_033357_738256"
#     },
#     "selfharm_score": {
#         "status": "Completed",
#         "duration": "0:00:54.940953",
#         "completed_lines": 9,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_2sonms1f_20250424_033357_906377"
#     },
#     "sexual_score": {
#         "status": "Completed",
#         "duration": "0:00:54.278814",
#         "completed_lines": 9,
#         "failed_lines": 0,
#         "log_path": "/home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_sau8q06s_20250424_033358_880047"
#     }
# }
#
# ====================================================
#
# https://ai.azure.com/build/evaluation/7b8df602-bb42-4182-9cf5-0714155096dd?wsid=/subscriptions/f08cda90-375b-4b3e-a105-4656379a94ab/resourceGroups/rg-Ziggy-ForEvaluation-AzureAIFoundry/providers/Microsoft.MachineLearningServices/workspaces/ZiggyEvalProject
# WARNING:opentelemetry.attributes:Invalid type dict for attribute '__computed__.cumulative_token_count.completion' value. Expected one of ['bool', 'str', 'bytes', 'int', 'float'] or a sequence of those types
# WARNING:opentelemetry.attributes:Invalid type dict for attribute '__computed__.cumulative_token_count.prompt' value. Expected one of ['bool', 'str', 'bytes', 'int', 'float'] or a sequence of those types
# WARNING:opentelemetry.attributes:Invalid type dict for attribute 'llm.usage.completion_tokens_details' value. Expected one of ['bool', 'str', 'bytes', 'int', 'float'] or a sequence of those types
# WARNING:opentelemetry.attributes:Invalid type dict for attribute 'llm.usage.prompt_tokens_details' value. Expected one of ['bool', 'str', 'bytes', 'int', 'float'] or a sequence of those types
# WARNING:opentelemetry.attributes:Invalid type dict for attribute '__computed__.cumulative_token_count.completion' value. Expected one of ['bool', 'str', 'bytes', 'int', 'float'] or a sequence of those types
# WARNING:opentelemetry.attributes:Invalid type dict for attribute '__computed__.cumulative_token_count.prompt' value. Expected one of ['bool', 'str', 'bytes', 'int', 'float'] or a sequence of those types
# {"score": 2, "explanation": "The response is mostly unfriendly, as it comes off as judgmental and dismissive."}

# %% [markdown]
# ## Assign yourself the Proper role to Track results in Azure AI Foundry
#
# 1. Get your user ID
#
# az ad signed-in-user show --query id --output tsv
#
# 2. Assign yourself the Storage Blob Data Contributor role in the Resource Group where the Azure AI Foundry project is. Replace the placeholder text with your subscription ID, resource group, and user ID.
#
# az role assignment create --role "Storage Blob Data Contributor" --scope /subscriptions/mySubscriptionID/resourceGroups/myResourceGroupName --assignee-principal-type User --assignee-object-id "user-id"
#
# Example: az role assignment create --role "Storage Blob Data Contributor" --scope /subscriptions/f08cda90-375b-4b3e-a105-4656379a94ab/reso
# urceGroups/rg-Ziggy-ForEvaluation-AzureAIFoundry --assignee-principal-type User --assignee-object-id effb07cd-dc40-4b91-a120-32464c95a844

# %% [markdown]
# ## Run Evaluation and Track in Azure AI Foundry

# %%
from azure.ai.evaluation import evaluate
from azure.ai.evaluation import GroundednessEvaluator, RetrievalEvaluator, RelevanceEvaluator, CoherenceEvaluator, FluencyEvaluator, SimilarityEvaluator, F1ScoreEvaluator
from azure.ai.evaluation import RougeScoreEvaluator, RougeType
from azure.ai.evaluation import BleuScoreEvaluator
from azure.ai.evaluation import MeteorScoreEvaluator
from azure.ai.evaluation import GleuScoreEvaluator
from azure.ai.evaluation import ViolenceEvaluator, HateUnfairnessEvaluator, SelfHarmEvaluator,SexualEvaluator
from azure.identity import DefaultAzureCredential
import pandas as pd

groundedness_eval = GroundednessEvaluator(model_config)
retrieval_eval = RetrievalEvaluator(model_config)
relevance_eval = RelevanceEvaluator(model_config)
coherence_eval = CoherenceEvaluator(model_config)
fluency_eval = FluencyEvaluator(model_config)
similarity_eval = SimilarityEvaluator(model_config)
f1_eval = F1ScoreEvaluator()
rouge_eval = RougeScoreEvaluator(rouge_type=RougeType.ROUGE_1)
bleu_eval = BleuScoreEvaluator()
meteor_eval = MeteorScoreEvaluator(
    alpha=0.9,
    beta=3.0,
    gamma=0.5
)
gleu_eval = GleuScoreEvaluator()
violence_eval = ViolenceEvaluator(azure_ai_project=azure_ai_project, credential=DefaultAzureCredential())
hateunfairness_eval = HateUnfairnessEvaluator(azure_ai_project=azure_ai_project, credential=DefaultAzureCredential())
selfharm_eval = SelfHarmEvaluator(azure_ai_project=azure_ai_project, credential=DefaultAzureCredential())
sexual_eval = SexualEvaluator(azure_ai_project=azure_ai_project, credential=DefaultAzureCredential())

path = "../Data/output/nasaeval.jsonl"

result = evaluate(
    data=path, # provide your data here
    evaluators={
        "groundedness": groundedness_eval,
        "retrieval": retrieval_eval,
        "relevance": relevance_eval,
        "coherence": coherence_eval,
        "fluency": fluency_eval,
        "similarity": similarity_eval,
        "f1_score": f1_eval,
        "rouge_score": rouge_eval,
        "bleu_score": bleu_eval,
        "meteor_score": meteor_eval,
        "gleu_score": gleu_eval,
        "violence_score": violence_eval,
        "hateunfairness_score": hateunfairness_eval,
        "selfharm_score": selfharm_eval,
        "sexual_score": sexual_eval 
    },
    # column mapping
    evaluator_config={
        "default": {
            "query": "${data.query}",
            "response": "${data.response}",
            "context": "${data.context}",
            "ground_truth": "${data.ground_truth}"
        }
    },
    azure_ai_project = azure_ai_project
)
# Out:
# [2025-04-24 03:33:52 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:33:52 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:33:52 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:33:52 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_vcik0ibh_20250424_033352_693010, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_vcik0ibh_20250424_033352_693010/logs.txt
# [2025-04-24 03:33:52 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_dk76k401_20250424_033352_684614, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_dk76k401_20250424_033352_684614/logs.txt
# [2025-04-24 03:33:52 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:33:52 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_h0201qll_20250424_033352_696203, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_h0201qll_20250424_033352_696203/logs.txt
# [2025-04-24 03:33:52 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:33:52 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_vcazc4jv_20250424_033352_707417, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_vcazc4jv_20250424_033352_707417/logs.txt
# [2025-04-24 03:33:52 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:33:52 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_94nwv3oe_20250424_033352_690157, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_94nwv3oe_20250424_033352_690157/logs.txt
# [2025-04-24 03:33:52 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_similarity_similarity_asyncsimilarityevaluator_q838i3xt_20250424_033352_701336, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_similarity_similarity_asyncsimilarityevaluator_q838i3xt_20250424_033352_701336/logs.txt
# Prompt flow service has started...
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_dk76k401_20250424_033352_684614
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_vcik0ibh_20250424_033352_693010
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_similarity_similarity_asyncsimilarityevaluator_q838i3xt_20250424_033352_701336
# Prompt flow service has started...
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_94nwv3oe_20250424_033352_690157
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_h0201qll_20250424_033352_696203
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_vcazc4jv_20250424_033352_707417
# [2025-04-24 03:33:55 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:33:55 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_f1_score_f1_score_asyncf1scoreevaluator_8da5rw2o_20250424_033355_151992, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_f1_score_f1_score_asyncf1scoreevaluator_8da5rw2o_20250424_033355_151992/logs.txt
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_f1_score_f1_score_asyncf1scoreevaluator_8da5rw2o_20250424_033355_151992
# [2025-04-24 03:33:56 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:33:56 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_rouge_rouge_asyncrougescoreevaluator_jrkztjww_20250424_033356_337376, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_rouge_rouge_asyncrougescoreevaluator_jrkztjww_20250424_033356_337376/logs.txt
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_rouge_rouge_asyncrougescoreevaluator_jrkztjww_20250424_033356_337376
# Prompt flow service has started...
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator_2p45ovqc_20250424_033357_192387
# [2025-04-24 03:33:57 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_meteor_meteor_asyncmeteorscoreevaluator_1a7uhhjm_20250424_033357_204832
# [2025-04-24 03:33:57 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:33:57 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator_2p45ovqc_20250424_033357_192387, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_bleu_bleu_asyncbleuscoreevaluator_2p45ovqc_20250424_033357_192387/logs.txt
# [2025-04-24 03:33:57 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_meteor_meteor_asyncmeteorscoreevaluator_1a7uhhjm_20250424_033357_204832, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_meteor_meteor_asyncmeteorscoreevaluator_1a7uhhjm_20250424_033357_204832/logs.txt
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_gleu_gleu_asyncgleuscoreevaluator_5m88k3_0_20250424_033357_447210
# 2025-04-24 03:33:57 +0000   50520 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# [2025-04-24 03:33:57 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# 2025-04-24 03:33:57 +0000   50520 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# [2025-04-24 03:33:57 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_gleu_gleu_asyncgleuscoreevaluator_5m88k3_0_20250424_033357_447210, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_gleu_gleu_asyncgleuscoreevaluator_5m88k3_0_20250424_033357_447210/logs.txt
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_u5m883ku_20250424_033357_647415
# [2025-04-24 03:33:57 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:33:57 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_u5m883ku_20250424_033357_647415, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_u5m883ku_20250424_033357_647415/logs.txt
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_uh1_x7fy_20250424_033357_738256
# [2025-04-24 03:33:57 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:33:58 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_uh1_x7fy_20250424_033357_738256, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_uh1_x7fy_20250424_033357_738256/logs.txt
# Prompt flow service has started...
# [2025-04-24 03:33:58 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:33:58 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_2sonms1f_20250424_033357_906377, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_2sonms1f_20250424_033357_906377/logs.txt
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_2sonms1f_20250424_033357_906377
# Prompt flow service has started...
# You can view the traces in local from http://127.0.0.1:23333/v1.0/ui/traces/?#run=azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_sau8q06s_20250424_033358_880047
# [2025-04-24 03:33:59 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-04-24 03:33:59 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_sau8q06s_20250424_033358_880047, log path: /home/codespace/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_sau8q06s_20250424_033358_880047/logs.txt
# 2025-04-24 03:34:35 +0000   50520 execution.bulk     INFO     Finished 6 / 9 lines.
# 2025-04-24 03:34:35 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.2 seconds. Estimated time for incomplete lines: 18.6 seconds.
# 2025-04-24 03:34:35 +0000   50520 execution.bulk     INFO     Finished 6 / 9 lines.
# 2025-04-24 03:34:35 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.11 seconds. Estimated time for incomplete lines: 18.33 seconds.
# 2025-04-24 03:34:51 +0000   50520 execution.bulk     INFO     Finished 4 / 9 lines.
# 2025-04-24 03:34:51 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 13.42 seconds. Estimated time for incomplete lines: 67.1 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 5 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 10.78 seconds. Estimated time for incomplete lines: 43.12 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 7 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 7.75 seconds. Estimated time for incomplete lines: 15.5 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 8 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.79 seconds. Estimated time for incomplete lines: 6.79 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.04 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 6 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 9.1 seconds. Estimated time for incomplete lines: 27.3 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 7 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 7.63 seconds. Estimated time for incomplete lines: 15.26 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 7 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 7.8 seconds. Estimated time for incomplete lines: 15.6 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 8 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.82 seconds. Estimated time for incomplete lines: 6.82 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 8 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.69 seconds. Estimated time for incomplete lines: 6.69 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 5.95 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Finished 9 / 9 lines.
# 2025-04-24 03:34:52 +0000   50520 execution.bulk     INFO     Average execution time for completed lines: 6.09 seconds. Estimated time for incomplete lines: 0.0 seconds.

# %% [markdown]
# ## View Evaluation Results
#
# Go to your project in Azure AI Foundry and view the results under the Evaluation tab

# %%
print(result['studio_url'])

# %% [markdown]
# ## Evaluate Using a Custom Evaluator

# %%
query="I have a problem with my computer"
response="What? why you spend so much time on that thing? You should be doing something else"

# %%
from promptflow.client import load_flow

friendliness_eval = load_flow(source="friendliness.prompty", model={"configuration": model_config})
friendliness_score = friendliness_eval(
    query=query,
    response=response
)
print(friendliness_score)
# Out:
# {"score": 1, "explanation": "The response is unfriendly and dismissive, showing a lack of understanding and empathy."}

# %%
query="I have a problem with my computer"
response="What the f**k? why you spend so much time on that thing? You should be doing something else!! Grrrr"

# %%
from promptflow.client import load_flow

friendliness_eval = load_flow(source="friendliness.prompty", model={"configuration": model_config})
friendliness_score = friendliness_eval(
    query=query,
    response=response
)
print(friendliness_score)
# Out:
# {"score": 1, "explanation": "The response is hostile, uses inappropriate language, and is not friendly or helpful."}

# %%
query="I have a problem with my computer"
response="I am sorry to hear that you are having a problem with your computer. Can you please provide more details about the issue? I will do my best to help you resolve it."

# %%
from promptflow.client import load_flow

friendliness_eval = load_flow(source="friendliness.prompty", model={"configuration": model_config})
friendliness_score = friendliness_eval(
    query=query,
    response=response
)
print(friendliness_score)
# Out:
# {"score": 5, "explanation": "The response is very friendly, expressing empathy and a willingness to help resolve the issue."}
