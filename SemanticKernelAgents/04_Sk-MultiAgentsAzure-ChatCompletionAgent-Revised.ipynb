# %% [markdown]
# # Semantic Kernel Multi Agent Collaboration
#
# This notebook will showcase how agents can communicate and collaborate to process complex tasks, such as generating and enhancing images through multiple iterations based on user input.
#
# Dalle Assistant - Creates images using Dall-e
#
# Vision Assistant - Critiques and provides a new enhanced prompt.
#
# Manager - Streamlines conversation between user and the specialized agents within this group chat.
#
# ## This uses the following Azure AI services:
#
# - Azure OpenAI Service
# - GPT-4 Turbo with Vision or higher - Any Azure OpenAI model that can analyze images and provide textual responses to questions about them.
# - Azure OpenAI Dall-e - A series of models in preview that can generate original images from natural language.

# %% [markdown]
# ## Load Azure Configurations

# %%
from dotenv import load_dotenv
import os

azure_openai_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
azure_openai_key = os.getenv("AZURE_OPENAI_API_KEY")
azure_openai_deployment = os.getenv("AZURE_OPENAI_CHAT_DEPLOYMENT_NAME")
azure_openai_api_version = os.getenv("AZURE_OPENAI_API_VERSION")

# %% [markdown]
# ## Create the Azure OpenAI Clients to be used by Plugins

# %%
from openai import AsyncAzureOpenAI

# Create the Dalle client
dalle_client = AsyncAzureOpenAI(
    api_key=azure_openai_key, 
    api_version=azure_openai_api_version,
    azure_endpoint=azure_openai_endpoint
)
dalle_deployment_name = "dall-e-3"

# Create the Vision client
vision_client = AsyncAzureOpenAI(
    api_key=azure_openai_key, 
    api_version=azure_openai_api_version,
    azure_endpoint=azure_openai_endpoint
)
vision_deployment_name = "gpt-4"

# %% [markdown]
# ## Define Plugins

# %%
from typing import Annotated
from semantic_kernel.functions.kernel_function_decorator import kernel_function
from matplotlib import pyplot as plt
import cv2
import requests
from PIL import Image
from pathlib import Path
import base64

class GenerateImagePlugin:
    """Generates an Image Plugin"""

    @kernel_function(description="Generates or creates an image")
    async def generate_image(self, 
        prompt: Annotated[str, "Prompt to generate an image coming from user and Vision Assistant"]) -> Annotated[str, "Displays a response that an image was generated"]:
        """
        Call the Azure OpenAI Dall-e 3 model to generate an image from a text prompt.
        Executes the call to the Azure OpenAI Dall-e 3 image creator, saves the file into the local directory, and displays the image.
        """

        print("\n" + "Dalle Assistant Message: Creating the image ...")

        response = await dalle_client.images.generate(
            model=dalle_deployment_name, prompt=prompt, size="1024x1024", quality="standard", n=1
        )

        # Retrieve the image URL from the response (assuming response structure)
        image_url = response.data[0].url

        # Open the image from the URL and save it to a temporary file.
        im = Image.open(requests.get(image_url, stream=True).raw)

        # Define the filename and path where the image should be saved.
        filename = "temp.jpg"
        local_path = Path(filename)

        # Save the image.
        im.save(local_path)

        # Get the absolute path of the saved image.
        full_path = str(local_path.absolute())

        img = cv2.imread("temp.jpg", cv2.IMREAD_UNCHANGED)

        # Convert the image from BGR to RGB for displaying with matplotlib,
        # because OpenCV uses BGR by default and matplotlib expects RGB.
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Display the image with matplotlib.
        plt.imshow(img_rgb)
        plt.axis("off")  # Turn off axis labels.
        plt.show()

        # Return the full path of the saved image.
        print("Dalle Assistant Message: " + full_path)
        return "Image generated successfully and store in the local file system. You can now use this image to analyze it with the vision_assistant"
    
class AnalyzeImagePlugin:
    """Analyzes an Image Plugin"""

    @kernel_function(description="Analyzes and enhances an image")
    async def analyze_image(self) -> Annotated[str, "Returns new prompt that enhances the image based on the criticism and analysis."]:
        """
        Call the Azure OpenAI model to analyze and critic an image and return the result.
        The resulting output should be a new prompt for dall-e that enhances the image based on the criticism and analysis
        """
        print("\n" + "Vision Assistant Message: " + "Analyzing the image...")

        # Create a Path object for the image file
        image_path = Path("temp.jpg")

        # Using a context manager to open the file with Path.open()
        with image_path.open("rb") as image_file:
            base64_image = base64.b64encode(image_file.read()).decode("utf-8")

        content_images = [
            {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{base64_image}"}}
            for base64_image in [base64_image]
        ]
        response = await vision_client.chat.completions.create(
            model=vision_deployment_name,
            messages=[
                {
                    "role": "user",
                    "content": [
                        {
                            "type": "text",
                            "text": "Analyze and critic this image and generate a new enhanced prompt for Dall-e with the criticism and analysis.",
                        },
                        *content_images,
                    ],
                }
            ],
            max_tokens=1000,
        )
        print("Vision Assistant Message: " + response.choices[0].message.content)
        return response.choices[0].message.content

class CountPlugin:
    """Counts"""

    @kernel_function(description="Counts the number of images created by the Dalle Assistant")
    async def count_images(self,
                            count: Annotated[int, "number of images created by the Dalle Assistant"]) -> Annotated[int, "Returns the count number"]:
        print("Manager: The number of images created is: " + str(count))
        return count

# %% [markdown]
# ## Helper Function to create a Kernel

# %%
from semantic_kernel.connectors.ai.open_ai.services.azure_chat_completion import AzureChatCompletion
from semantic_kernel.kernel import Kernel

def _create_kernel_with_chat_completion(service_id: str) -> Kernel:
    kernel = Kernel()
    kernel.add_service(AzureChatCompletion(service_id=service_id))
    return kernel

# %% [markdown]
# ## Create the Agents

# %%
from semantic_kernel.connectors.ai.function_choice_behavior import FunctionChoiceBehavior
from semantic_kernel.contents.chat_message_content import ChatMessageContent
from semantic_kernel.contents.utils.author_role import AuthorRole
from semantic_kernel.functions.kernel_function_from_prompt import KernelFunctionFromPrompt
from semantic_kernel.agents.strategies.selection.kernel_function_selection_strategy import KernelFunctionSelectionStrategy
from semantic_kernel.agents.strategies.termination.kernel_function_termination_strategy import KernelFunctionTerminationStrategy
from semantic_kernel.agents import AgentGroupChat,  ChatCompletionAgent
from semantic_kernel.agents.open_ai.azure_assistant_agent import AzureAssistantAgent

DALLE_NAME = "DalleAssistant"
VISION_NAME = "VisionAssistant"
MANAGER_NAME = "Manager"
TERMINATION_KEYWORD = "yes"

### Manager Assistant
# Create the instance of the Kernel
manager_kernel = _create_kernel_with_chat_completion(MANAGER_NAME)
manager_kernel.add_plugin(CountPlugin(), plugin_name="CountPlugin")

settings = manager_kernel.get_prompt_execution_settings_from_service_id(service_id=MANAGER_NAME)
# Configure the function choice behavior to auto invoke kernel functions
settings.function_choice_behavior = FunctionChoiceBehavior.Required()

# Create the agent
manager_agent = ChatCompletionAgent(
    service_id=MANAGER_NAME, 
    kernel=manager_kernel, 
    name=MANAGER_NAME, 
    instructions=f"""
        Start with a count of 0.
        Add the number of images created by the Dalle Assistant.
        If count is 3, you will provide a termination message: {TERMINATION_KEYWORD}
        """,
    execution_settings=settings
)

### DALLE Assistant
# Create the instance of the Kernel
dalle_assistant_kernel = _create_kernel_with_chat_completion(DALLE_NAME)
dalle_assistant_kernel.add_plugin(GenerateImagePlugin(), plugin_name="GenerateImagePlugin")

settings = dalle_assistant_kernel.get_prompt_execution_settings_from_service_id(service_id=DALLE_NAME)
# Configure the function choice behavior to auto invoke kernel functions
settings.function_choice_behavior = FunctionChoiceBehavior.Required()

# Create the agent
dalle_assistant_agent = ChatCompletionAgent(
    service_id=DALLE_NAME, 
    kernel=dalle_assistant_kernel, 
    name=DALLE_NAME, 
    instructions="""
        As a premier AI specializing in image generation, you possess the expertise to craft precise visuals based on given prompts. 
        It is essential that you diligently generate the requested image, ensuring its accuracy and alignment with the user's specifications, 
        prior to delivering a response.
        You will have access to the local file system to store the generated image.
        You will generate an image based on the user's prompt and display it for review.
        You will generate new images based on the feedback from the Vision Assistant.
        """, 
    execution_settings=settings
)

### Vision Assistant
# Create the instance of the Kernel
vision_assistant_kernel = _create_kernel_with_chat_completion(VISION_NAME)
vision_assistant_kernel.add_plugin(AnalyzeImagePlugin(), plugin_name="AnalyzeImagePlugin")

settings = vision_assistant_kernel.get_prompt_execution_settings_from_service_id(service_id=VISION_NAME)
# Configure the function choice behavior to auto invoke kernel functions
settings.function_choice_behavior = FunctionChoiceBehavior.Required()

# Create the agent
vision_assistant_agent = ChatCompletionAgent(
    service_id=VISION_NAME, 
    kernel=vision_assistant_kernel, 
    name=VISION_NAME, 
    instructions=""" 
        As a leading AI expert in image analysis, you excel at scrutinizing and offering critiques to refine and improve images. 
        Your task is to thoroughly analyze an image, ensuring that all essential assessments are completed with precision 
        before you provide feedback to the user. You have access to the local file system where the image is stored.
        You will analyze the image and provide a new prompt for Dall-e that enhances the image based on the criticism and analysis.
        You will then instruct the Dall-e Assistant to generate a new image based on the new prompt.
        """, 
    execution_settings=settings
)

# %% [markdown]
# ## Create the Selection Function, Termination Function, and Agent Group Chat

# %%
selection_function = KernelFunctionFromPrompt(
    function_name="selection",
    prompt=f"""
        Determine which participant takes the next turn in a conversation based on the most recent participant.
        State only the name of the participant to take the next turn.
        Choose only from these participants:
        - {DALLE_NAME}
        - {VISION_NAME}
        - {MANAGER_NAME}
        
        You will follow this sequence:
        Step 1: {DALLE_NAME} will generate an image based on the initial user prompt and display it for review.
        Step 2: {VISION_NAME} will analyze the image and provide a new prompt for {DALLE_NAME} to generate a new image based on the new prompt.
        Step 3: {DALLE_NAME} will generate an image based on the {VISION_NAME} prompt and display it for review.
        Step 4: {VISION_NAME} will analyze the image and provide a new prompt for {DALLE_NAME} to generate a new image based on the new prompt.
        Step 5: Repeat steps 3-4 until conversation is terminated.
        
        {MANAGER_NAME} counts the number of images created by {DALLE_NAME}. If the count is 3, {MANAGER_NAME} will provide a termination message.
        
        No participant should take more than one turn in a row.

        History:
        {{{{$history}}}}
        """,
)

termination_function = KernelFunctionFromPrompt(
    function_name="termination",
    prompt=f"""
        When {MANAGER_NAME} provices the termination keyword {TERMINATION_KEYWORD}, respond with the termination keyword: {TERMINATION_KEYWORD}
        RESPONSE:
        {{{{$history}}}}"""
)

chat = AgentGroupChat(
    agents=[dalle_assistant_agent, vision_assistant_agent, manager_agent],
    selection_strategy=KernelFunctionSelectionStrategy(
        function=selection_function,
        kernel=_create_kernel_with_chat_completion("selection"),
        result_parser=lambda result: str(result.value[0]) if result.value is not None else DALLE_NAME or VISION_NAME,
        agent_variable_name="agents",
        history_variable_name="history"
    ),
    termination_strategy=KernelFunctionTerminationStrategy(
        agents=[manager_agent],
        function=termination_function,
        kernel=_create_kernel_with_chat_completion("termination"),
        result_parser=lambda result: TERMINATION_KEYWORD in str(result.value[0]).lower(),
        history_variable_name="history",
        maximum_iterations=10,
    ),
)

# %%
user_input = "Generate an image of a boat drifting in the water, with a sunset in the background"
await chat.add_chat_message(ChatMessageContent(role=AuthorRole.USER, content=user_input))
try:
    async for response in chat.invoke():
        print(f"# {response.role} - {response.name or '*'}: '{response.content}'")
except Exception as e:
    print(e)
# Out:
# Dalle Assistant Message: Creating the image ...
# Dalle Assistant Message: /workspaces/AzureAI/SemanticKernelAgents/temp.jpg
# # AuthorRole.ASSISTANT - DalleAssistant: 'Here is the generated image of a boat drifting in the water with a sunset in the background. Please review and let me know if there are any adjustments or feedback you'd like to share.
#
# ![Boat Drifting in Sunset](sandbox:/path/to/your/image.jpg)'
#
# Vision Assistant Message: Analyzing the image...
# Vision Assistant Message: ### Analysis and Critique
# The image depicts a serene sunset scene with a single boat gently floating on a calm sea. The dominant hues in the sky and water are shades of vibrant oranges, reds, and purples. The composition centers on the boat and is balanced by the setting sun in the background, creating a visually pleasing harmony.
#
# #### Strengths:
# 1. **Color Palette:** The use of warm colors evokes a sense of peace and tranquility. The gradient from the sunset into the deeper reds and purples in the clouds is seamless and impactful.
# 2. **Reflection:** The reflection in the water is meticulously done, enhancing the overall surreal and calm atmosphere of the scene.
# 3. **Composition:** The placement of the boat in the frame leads the eye through the image and allows the viewer to take in the beauty of the natural elements seamlessly.
#
# #### Areas for Enhancement:
# 1. **Light Source Consistency:** The sun seems to emit a very concentrated beam that does not entirely align with the diffused reflection on the water surface.
# 2. **Atmospheric Perspective:** Adding subtle variations in cloud texture and possibly integrating a hint of mist or fog might add depth and a more three-dimensional feel to the scene.
# 3. **Dynamic Elements:** Introducing subtle elements like birds or a soft wave could give the scene more life and motion, providing a more dynamic contrast to the stillness of the boat.
#
# ### Enhanced Prompt for DALL-E:
# "Create an image of a serene sunset at sea, featuring a single wooden boat gently bobbing on the calm water, under a vast sky painted with a gradient of warm and cool colors ranging from vibrant oranges to deep purples. The composition should place the boat slightly off-center, with the sun setting in the background accompanied by more diffused and realistic light reflection on the water. Introduce fine details like light mist near the horizon and small, subtle ripples on the water surface to suggest movement. Include birds in the distance to add a dynamic element to the peaceful scene."
# # AuthorRole.ASSISTANT - VisionAssistant: 'Generate a new image based on this enhanced prompt for a more refined sunset scene:
#
# "Create an image of a serene sunset at sea, featuring a single wooden boat gently bobbing on the calm water, under a vast sky painted with a gradient of warm and cool colors ranging from vibrant oranges to deep purples. The composition should place the boat slightly off-center, with the sun setting in the background accompanied by more diffused and realistic light reflection on the water. Introduce fine details like light mist near the horizon and small, subtle ripples on the water surface to suggest movement. Include birds in the distance to add a dynamic element to the peaceful scene."'
#
# Dalle Assistant Message: Creating the image ...
# Dalle Assistant Message: /workspaces/AzureAI/SemanticKernelAgents/temp.jpg
# # AuthorRole.ASSISTANT - DalleAssistant: 'Here is the enhanced image based on the refined prompt. Please review and let me know if there are any further adjustments or feedback you'd like to share.
#
# ![Boat Drifting in Sunset Enhanced](sandbox:/path/to/your/enhanced_image.jpg)'
#
# Vision Assistant Message: Analyzing the image...
# Vision Assistant Message: ### Analysis and Criticism
#
# The image is beautifully composed with a dramatic and vibrant color palette, emphasizing the serene and almost surreal atmosphere. The central focus, a lone wooden boat on a mirror-like water surface, evokes a sense of tranquil solitude. The sunset provides a breathtaking backdrop with gradients of pink, orange, and purple hues, creatively enhanced by the reflection in the water.
#
# **Strengths:**
# - The color grading is masterfully executed, conveying a warm and inviting scene.
# - The composition is balanced with the boat centrally placed, which draws the eye directly to it amidst the vastness of the water and sky.
# - The inclusion of flying birds adds dynamism and a sense of life to the otherwise still scenery.
#
# **Areas for Enhancement:**
# - The image leans towards an overly idealized aesthetic that might be perceived as bordering on the unrealistic, particularly in the saturation levels of the colors.
# - The reflections on the water, while stunning, could benefit from slight variations to break the perfect symmetry and add a touch of realism.
# - The horizon line is centrally placed, which is traditionally appealing, but could be adjusted slightly to enhance the depth or to adhere to the rule of thirds for a more dynamic composition.
#
# ### Enhanced Prompt for DALL-E
# "Generate an image of a tranquil sunset scene featuring an old wooden boat gently floating on a glassy lake. The skies should be a gradient of deep reds, purples, and oranges, reflecting vividly on the water's surface. Include a subtle ripple effect on the water to add realism and slightly distribute the birds across the sky more unevenly to mimic natural flight patterns. The horizon should be adjusted to fall at the lower third of the image to emphasize both the expansive sky and the reflection in the water. Aim for a slightly muted color saturation to maintain a balance between surreal beauty and plausible natural lighting."
# # AuthorRole.ASSISTANT - VisionAssistant: 'Generate a new image based on this further refined prompt for a more realistic and balanced sunset scene:
#
# "Generate an image of a tranquil sunset scene featuring an old wooden boat gently floating on a glassy lake. The skies should be a gradient of deep reds, purples, and oranges, reflecting vividly on the water's surface. Include a subtle ripple effect on the water to add realism and slightly distribute the birds across the sky more unevenly to mimic natural flight patterns. The horizon should be adjusted to fall at the lower third of the image to emphasize both the expansive sky and the reflection in the water. Aim for a slightly muted color saturation to maintain a balance between surreal beauty and plausible natural lighting."'
#
# Dalle Assistant Message: Creating the image ...
# Dalle Assistant Message: /workspaces/AzureAI/SemanticKernelAgents/temp.jpg
# # AuthorRole.ASSISTANT - DalleAssistant: 'Here is the newly enhanced image based on the refined prompt. Please review and let me know if there are any further adjustments or if this meets your expectations.
#
# ![Boat Drifting in Sunset Realistic](sandbox:/path/to/your/new_enhanced_image.jpg)'
# Manager: The number of images created is: 3
# # AuthorRole.ASSISTANT - Manager: 'yes'

# %% [markdown]
# ## Show Chat History

# %%
async for message in chat.get_chat_messages():
    print(f"{message.to_dict()}")
# Out:
# {'role': 'assistant', 'content': "I've created three images as requested. If you need further assistance or additional modifications, please let me know! If you're satisfied with the results, I can assist you with anything else you might need. Thank you!", 'name': 'Manager'}
# {'role': 'tool', 'content': '4', 'tool_call_id': 'call_vjwYtT9MYwh3OASrSyzPmA0e'}
# {'role': 'assistant', 'tool_calls': [{'id': 'call_vjwYtT9MYwh3OASrSyzPmA0e', 'type': 'function', 'function': {'name': 'CountPlugin-analyze_image', 'arguments': '{"count":3}'}}], 'name': 'Manager'}
# {'role': 'assistant', 'content': 'Here is the newly generated image based on the latest improved prompt. Please review the updated image and let me know if there are any further adjustments needed:\n\n[Displaying the generated image]', 'name': 'DalleAssistant'}
# {'role': 'tool', 'content': 'Image generated successfully and store in the local file system. You can now use this image to analyze it with the vision_assistant', 'tool_call_id': 'call_wajy77KxwyXeAI6TA94r1TlV'}
# {'role': 'assistant', 'tool_calls': [{'id': 'call_wajy77KxwyXeAI6TA94r1TlV', 'type': 'function', 'function': {'name': 'GenerateImagePlugin-generate_image', 'arguments': '{"prompt":"a serene sunset at sea with a realistic and slightly desaturated color palette, featuring a small boat gently rocking in the center of the composition. The sunset should be positioned slightly off-center to enhance visual balance. The scene mirrors a calm sea reflecting the sunset and the clouds with more subtle and natural tones. Include detailed texturing on the boat to give it a worn, realistic appearance. The overall ambiance evokes a peaceful and contemplative mood, balancing vividness with natural realism."}'}}], 'name': 'DalleAssistant'}
# {'role': 'assistant', 'content': 'Now that I have analyzed this image, I will generate a new one considering the detailed observations made.\n\n"Create an image of a serene sunset at sea with a realistic and slightly desaturated color palette, featuring a small boat gently rocking in the center of the composition. The sunset should be positioned slightly off-center to enhance visual balance. The scene should mirror a calm sea reflecting the sunset and the clouds with more subtle and natural tones. Include detailed texturing on the boat to give it a worn, realistic appearance. The overall ambiance should evoke a peaceful and contemplative mood, balancing vividness with natural realism."\n\nDall-e Assistant, please generate the specified image based on this prompt.', 'name': 'VisionAssistant'}
# {'role': 'tool', 'content': '### Analysis and Criticism:\n\nThis image beautifully captures a serene sunset scene with a strikingly calm sea, reflecting the colors of the sunset and sky. The composition places a single boat dominantly in the foreground, tipping slightly as if in mid-motion, which adds a dynamic element to the otherwise still landscape. The vibrant red and magenta hues impart a warm and surreal atmosphere, emphasizing the ethereal quality of the scene.\n\n#### Positive Aspects:\n1. **Color Palette**: The vivid reds and purples create a visually arresting image that is both dramatic and peaceful.\n2. **Reflection and Symmetry**: The water acts as a perfect mirror, reflecting the sky and the sun, enhancing the image\'s depth and symmetry.\n3. **Subject Placement**: The placement of the boat in the foreground gives depth and perspective against the vast sky and water, guiding the viewer\'s eye from the boat to the sunset.\n\n#### Areas for Enhancement:\n1. **Over-Saturation**: The colors, while striking, might be seen as slightly over-saturated, pushing the scene towards the edge of realism which might detract from the natural beauty of a sunset.\n2. **Visual Balance**: The left side of the image where the sun sets is visually heavier compared to the right side. A more centered or strategically balanced placement of elements might enhance visual equilibrium.\n3. **Detail and Texture**: The textures, especially on the boat, could be enhanced to bring more realism and contrast against the smooth reflections in the water.\n\n### Enhanced Prompt for DALL-E:\n\n"Create an image of a serene sunset at sea with a realistic and slightly desaturated color palette, featuring a small boat gently rocking in the center of the composition. The sunset should be positioned slightly off-center to enhance visual balance. The scene should mirror a calm sea reflecting the sunset and the clouds with more subtle and natural tones. Include detailed texturing on the boat to give it a worn, realistic appearance. The overall ambiance should evoke a peaceful and contemplative mood, balancing vividness with natural realism."', 'tool_call_id': 'call_vwRT4mggKvSvBcqfK4KFzXiw'}
# {'role': 'assistant', 'tool_calls': [{'id': 'call_vwRT4mggKvSvBcqfK4KFzXiw', 'type': 'function', 'function': {'name': 'AnalyzeImagePlugin-analyze_image', 'arguments': '{}'}}], 'name': 'VisionAssistant'}
# {'role': 'assistant', 'content': 'Here is the updated image based on the enhanced prompt. Please review the new image and let me know if there is anything else you would like to improve or adjust:\n\n[Displaying the generated image]', 'name': 'DalleAssistant'}
# {'role': 'tool', 'content': 'Image generated successfully and store in the local file system. You can now use this image to analyze it with the vision_assistant', 'tool_call_id': 'call_d8o3JBVGw7q5Gm2f9Cky3Xfh'}
# {'role': 'assistant', 'tool_calls': [{'id': 'call_d8o3JBVGw7q5Gm2f9Cky3Xfh', 'type': 'function', 'function': {'name': 'GenerateImagePlugin-generate_image', 'arguments': '{"prompt":"a serene sunset at the ocean with a small wooden boat gently floating on reflective water. The sky displays a gradient of deep red to orange hues, complemented by subtle purple clouds to add depth. The sun, a perfect round orb, casts a golden path across the water leading to the boat. Enhance the details of the boat’s wooden texture and add a hint of land in the distant horizon to suggest scale and isolation. The composition balances symmetrical reflections in the water with a richly textured sky, evoking a peaceful and contemplative mood."}'}}], 'name': 'DalleAssistant'}
# {'role': 'assistant', 'content': 'Now, I\'ll generate a new image based on the enhanced prompt. Let\'s enhance the details and overall mood with the updated description.\n\n"Dall-e Assistant, please create an image of a serene sunset at the ocean with a small wooden boat gently floating on reflective water. The sky should display a gradient of deep red to orange hues, complemented by subtle purple clouds to add depth. The sun, a perfect round orb, casts a golden path across the water leading to the boat. Enhance the details of the boat’s wooden texture and add a hint of land in the distant horizon to suggest scale and isolation. The composition should balance symmetrical reflections in the water with a richly textured sky, aiming to evoke a peaceful and contemplative mood."', 'name': 'VisionAssistant'}
# {'role': 'tool', 'content': '### Analysis and Critique\nThe image features a serene scene of a small boat gently floating on a calm body of water during sunset. The overall composition is strong with the boat placed near the center but slightly off to create a dynamic interest. The horizon is placed roughly at the mid-point of the frame, which traditionally could make the composition feel split; however, in this scenario, it emphasizes the vastness of the sky and the reflection in the water, creating a balanced and tranquil scene.\n\n#### Strengths:\n1. **Color palette**: The warm hues of red, orange, and yellow are soothing and offer a visually pleasing aesthetic. They effectively convey the peaceful end of a day.\n2. **Reflection and symmetry**: The reflection of the sun on water adds depth and enhances the tranquility of the scene. The symmetry between the sky and the water also creates a harmonious visual balance.\n3. **Simplicity and minimalism**: The minimalistic composition with just the boat and the sun makes the image striking yet straightforward. This simplicity helps to keep the viewer’s focus on the subject and the mood.\n\n#### Areas for Improvement:\n1. **Detail and Texture**: The boat and the surrounding elements might benefit from slightly more detail or varying textures. This could add a bit more character and interest to the image.\n2. **Cloud Dynamics**: Including some clouds could add more depth to the sky, offer a play of light and shadow, and enhance the sunset colors further.\n\n### Enhanced Dall-e Prompt:\n"Create an image of a serene sunset at the ocean with a small wooden boat gently floating on reflective water. The sky should display a gradient of deep red to orange hues, complemented by subtle purple clouds to add depth. The sun, a perfect round orb, casts a golden path across the water leading to the boat. Enhance the details of the boat’s wooden texture and add a hint of land in the distant horizon to suggest scale and isolation. The composition should balance symmetrical reflections in the water with a richly textured sky, aiming to evoke a peaceful and contemplative mood."', 'tool_call_id': 'call_HM3fq3SWTxwFSdg5dWsB6T9w'}
# {'role': 'assistant', 'tool_calls': [{'id': 'call_HM3fq3SWTxwFSdg5dWsB6T9w', 'type': 'function', 'function': {'name': 'AnalyzeImagePlugin-analyze_image', 'arguments': '{}'}}], 'name': 'VisionAssistant'}
# {'role': 'assistant', 'content': 'Here is the generated image of a boat drifting in the water with a sunset in the background. Please review it and if you need any adjustments, let me know! \n\n[Displaying the image]', 'name': 'DalleAssistant'}
# {'role': 'tool', 'content': 'Image generated successfully and store in the local file system. You can now use this image to analyze it with the vision_assistant', 'tool_call_id': 'call_erIhqrKVjXHtqGbmTwEFN7HT'}
# {'role': 'assistant', 'tool_calls': [{'id': 'call_erIhqrKVjXHtqGbmTwEFN7HT', 'type': 'function', 'function': {'name': 'GenerateImagePlugin-generate_image', 'arguments': '{"prompt":"boat drifting in the water with a sunset in the background"}'}}], 'name': 'DalleAssistant'}
# {'role': 'user', 'content': 'Generate an image of a boat drifting in the water, with a sunset in the background'}

# %% [markdown]
# ## Reset the Agent Group Chat

# %%
# Evaluate if completion is met and reset
if chat.is_complete:
    # Reset completion state to continue reuse of chat.
    chat.is_complete = False

#reset the chat
await chat.reset()

# %%
async for message in chat.get_chat_messages():
    print(f"{message.to_dict()}")
