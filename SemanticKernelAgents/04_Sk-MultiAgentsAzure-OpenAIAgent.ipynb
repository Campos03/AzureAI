# %% [markdown]
# # Semantic Kernel Multi Agent Collaboration

# %% [markdown]
# ## Load Azure Configurations

# %%
from dotenv import load_dotenv
import os

azure_openai_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
azure_openai_key = os.getenv("AZURE_OPENAI_API_KEY")
azure_openai_deployment = os.getenv("AZURE_OPENAI_CHAT_DEPLOYMENT_NAME")
azure_openai_api_version = os.getenv("AZURE_OPENAI_API_VERSION")

# %% [markdown]
# ## Create the Azure OpenAI Clients to be used by Plugins

# %%
from openai import AsyncAzureOpenAI

# Create the Dalle client
dalle_client = AsyncAzureOpenAI(
    api_key=azure_openai_key, 
    api_version=azure_openai_api_version,
    azure_endpoint=azure_openai_endpoint
)
dalle_deployment_name = "dall-e-3"

# Create the Vision client
vision_client = AsyncAzureOpenAI(
    api_key=azure_openai_key, 
    api_version=azure_openai_api_version,
    azure_endpoint=azure_openai_endpoint
)
vision_deployment_name = "gpt-4"

# %% [markdown]
# ## Define Plugins

# %%
from typing import Annotated
from semantic_kernel.functions.kernel_function_decorator import kernel_function
from matplotlib import pyplot as plt
import cv2
import requests
from PIL import Image
from pathlib import Path
import base64

class GenerateImagePlugin:
    """Generates an Image Plugin"""

    @kernel_function(description="Generates or creates an image")
    async def generate_image(self, 
        prompt: Annotated[str, "Prompt to generate an image coming from user and Vision Assistant"]) -> Annotated[str, "Displays a response that an image was generated"]:
        """
        Call the Azure OpenAI Dall-e 3 model to generate an image from a text prompt.
        Executes the call to the Azure OpenAI Dall-e 3 image creator, saves the file into the local directory, and displays the image.
        """

        print("Dalle Assistant Message: Creating the image ...")

        response = await dalle_client.images.generate(
            model=dalle_deployment_name, prompt=prompt, size="1024x1024", quality="standard", n=1
        )

        # Retrieve the image URL from the response (assuming response structure)
        image_url = response.data[0].url

        # Open the image from the URL and save it to a temporary file.
        im = Image.open(requests.get(image_url, stream=True).raw)

        # Define the filename and path where the image should be saved.
        filename = "temp.jpg"
        local_path = Path(filename)

        # Save the image.
        im.save(local_path)

        # Get the absolute path of the saved image.
        full_path = str(local_path.absolute())

        img = cv2.imread("temp.jpg", cv2.IMREAD_UNCHANGED)

        # Convert the image from BGR to RGB for displaying with matplotlib,
        # because OpenCV uses BGR by default and matplotlib expects RGB.
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Display the image with matplotlib.
        plt.imshow(img_rgb)
        plt.axis("off")  # Turn off axis labels.
        plt.show()

        # Return the full path of the saved image.
        print("Dalle Assistant Message: " + full_path)
        return "Image generated successfully and store in the local file system. You can now use this image to analyze it with the VisionAssistant"
    
class AnalyzeImagePlugin:
    """Analyzes an Image Plugin"""

    @kernel_function(description="Analyzes and enhances an image")
    async def analyze_image(self) -> Annotated[str, "Returns new prompt that enhances the image based on the criticism and analysis."]:
        """
        Call the Azure OpenAI GPT4 Vision model to analyze and critic an image and return the result.
        The resulting output should be a new prompt for dall-e that enhances the image based on the criticism and analysis
        """
        print("Vision Assistant Message: " + "Analyzing the image...")

        # Create a Path object for the image file
        image_path = Path("temp.jpg")

        # Using a context manager to open the file with Path.open()
        with image_path.open("rb") as image_file:
            base64_image = base64.b64encode(image_file.read()).decode("utf-8")

        content_images = [
            {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{base64_image}"}}
            for base64_image in [base64_image]
        ]
        response = await vision_client.chat.completions.create(
            model=vision_deployment_name,
            messages=[
                {
                    "role": "user",
                    "content": [
                        {
                            "type": "text",
                            "text": "Analyze and critic this image and generate a new enhanced prompt for Dall-e with the criticism and analysis.",
                        },
                        *content_images,
                    ],
                }
            ],
            max_tokens=1000,
        )
        print("Vision Assistant Message: " + response.choices[0].message.content)
        return response.choices[0].message.content
    
class CountPlugin:
    """Counts"""

    @kernel_function(description="Counts the number of images created by the Dalle Assistant")
    async def count_images(self,
                            count: Annotated[int, "number of images created by the Dalle Assistant"]) -> Annotated[int, "Returns the count number"]:
        print("Manager: The number of images created is: " + str(count))
        return count

# %% [markdown]
# ## Helper Function to create a Kernel

# %%
from semantic_kernel.connectors.ai.open_ai.services.azure_chat_completion import AzureChatCompletion
from semantic_kernel.kernel import Kernel

def _create_kernel_with_chat_completion(service_id: str) -> Kernel:
    kernel = Kernel()
    kernel.add_service(AzureChatCompletion(service_id=service_id))
    return kernel

# %% [markdown]
# ## Create the Agents

# %%
from semantic_kernel.connectors.ai.function_choice_behavior import FunctionChoiceBehavior
from semantic_kernel.contents.chat_message_content import ChatMessageContent
from semantic_kernel.contents.utils.author_role import AuthorRole
from semantic_kernel.functions.kernel_function_from_prompt import KernelFunctionFromPrompt
from semantic_kernel.agents.strategies.selection.kernel_function_selection_strategy import KernelFunctionSelectionStrategy
from semantic_kernel.agents.strategies.termination.kernel_function_termination_strategy import KernelFunctionTerminationStrategy
from semantic_kernel.agents import AgentGroupChat,  ChatCompletionAgent
from semantic_kernel.agents.open_ai.azure_assistant_agent import AzureAssistantAgent
from semantic_kernel.connectors.ai.open_ai.prompt_execution_settings.azure_chat_prompt_execution_settings import AzureChatPromptExecutionSettings

DALLE_NAME = "DalleAssistant"
VISION_NAME = "VisionAssistant"
MANAGER_NAME = "Manager"
TERMINATION_KEYWORD = "yes"

### Manager Assistant
# Create the instance of the Kernel
manager_kernel = _create_kernel_with_chat_completion(MANAGER_NAME)
manager_kernel.add_plugin(CountPlugin(), plugin_name="CountPlugin")

# Create the agent
manager_agent = await AzureAssistantAgent.create(
    service_id=MANAGER_NAME, 
    kernel=manager_kernel, 
    name=MANAGER_NAME, 
    instructions=f"""
        Start with a count of 0.
        Add the number of images created by the Dalle Assistant.
        If count is 3, you will provide a termination message: {TERMINATION_KEYWORD}
        """
)

### DALLE Assistant
# Create the instance of the Kernel
dalle_assistant_kernel = _create_kernel_with_chat_completion(DALLE_NAME)
dalle_assistant_kernel.add_plugin(GenerateImagePlugin(), plugin_name="GenerateImagePlugin")

# Create the agent
dalle_assistant_agent = await AzureAssistantAgent.create(
    service_id=DALLE_NAME, 
    kernel=dalle_assistant_kernel, 
    name=DALLE_NAME, 
    instructions="""
        As a premier AI specializing in image generation, you possess the expertise to craft precise visuals based on given prompts. 
        It is essential that you diligently generate the requested image, ensuring its accuracy and alignment with the user's specifications, 
        prior to delivering a response.
        You will have access to the local file system to store the generated image.
        You will generate an image based on the user's prompt and display it for review.
        You will generate new images based on the feedback from the Vision Assistant.
        """, 
)

### Vision Assistant
# Create the instance of the Kernel
vision_assistant_kernel = _create_kernel_with_chat_completion(VISION_NAME)
vision_assistant_kernel.add_plugin(AnalyzeImagePlugin(), plugin_name="AnalyzeImagePlugin")

# Create the agent
vision_assistant_agent = await AzureAssistantAgent.create(
    service_id=VISION_NAME, 
    kernel=vision_assistant_kernel, 
    name=VISION_NAME, 
    instructions=""" 
        As a leading AI expert in image analysis, you excel at scrutinizing and offering critiques to refine and improve images. 
        Your task is to thoroughly analyze an image, ensuring that all essential assessments are completed with precision 
        before you provide feedback to the user. You have access to the local file system where the image is stored.
        You will analyze the image and provide a new prompt for Dall-e that enhances the image based on the criticism and analysis.
        You will then instruct the Dall-e Assistant to generate a new image based on the new prompt.
        """,
)

# %% [markdown]
# ## Create the Selection Function, Termination Function, and Agent Group Chat

# %%
selection_function = KernelFunctionFromPrompt(
    function_name="selection",
    prompt=f"""
        Determine which participant takes the next turn in a conversation based on the most recent participant.
        State only the name of the participant to take the next turn.
        Choose only from these participants:
        - {DALLE_NAME}
        - {VISION_NAME}
        - {MANAGER_NAME}
        
        You will follow this sequence:
        Step 1: {DALLE_NAME} will generate an image based on the initial user prompt and display it for review.
        Step 2: {VISION_NAME} will analyze the image and provide a new prompt for {DALLE_NAME} to generate a new image based on the new prompt.
        Step 3: {DALLE_NAME} will generate an image based on the {VISION_NAME} prompt and display it for review.
        Step 4: {VISION_NAME} will analyze the image and provide a new prompt for {DALLE_NAME} to generate a new image based on the new prompt.
        Step 5: Repeat steps 3-4 until conversation is terminated.
        
        {MANAGER_NAME} counts the number of images created by {DALLE_NAME}. If the count is 3, {MANAGER_NAME} will provide a termination message.
        
        No participant should take more than one turn in a row.

        History:
        {{{{$history}}}}
        """,
)

termination_function = KernelFunctionFromPrompt(
    function_name="termination",
    prompt=f"""
        When {MANAGER_NAME} provices the termination keyword {TERMINATION_KEYWORD}, respond with the termination keyword: {TERMINATION_KEYWORD}
        RESPONSE:
        {{{{$history}}}}"""
)

chat = AgentGroupChat(
    agents=[dalle_assistant_agent, vision_assistant_agent, manager_agent],
    selection_strategy=KernelFunctionSelectionStrategy(
        function=selection_function,
        kernel=_create_kernel_with_chat_completion("selection"),
        result_parser=lambda result: str(result.value[0]) if result.value is not None else DALLE_NAME or VISION_NAME,
        agent_variable_name="agents",
        history_variable_name="history"
    ),
    termination_strategy=KernelFunctionTerminationStrategy(
        agents=[manager_agent],
        function=termination_function,
        kernel=_create_kernel_with_chat_completion("termination"),
        result_parser=lambda result: TERMINATION_KEYWORD in str(result.value[0]).lower(),
        history_variable_name="history",
        maximum_iterations=10,
    ),
)

# %%
user_input = "Generate an image of a boat drifting in the water, with a sunset in the background."
await chat.add_chat_message(ChatMessageContent(role=AuthorRole.USER, content=user_input))
try:
    async for response in chat.invoke():
        print(f"# {response.role} - {response.name or '*'}: '{response.content}'")
except Exception as e:
    print(e)
# Out:
# Dalle Assistant Message: Creating the image ...
# Dalle Assistant Message: /workspaces/AzureAI/SemanticKernelAgents/temp.jpg
# # AuthorRole.ASSISTANT - DalleAssistant: 'The image of a boat drifting in the water with a sunset in the background has been generated successfully. Here it is for your review:
#
# ![Boat at Sunset](sandbox:/path/to/generated/image/boat_sunset.jpg)
#
# Please let me know if there are any adjustments you would like to make or if this meets your expectations.'
# Vision Assistant Message: Analyzing the image...
# Vision Assistant Message: ### Critique and Analysis
# The image shows a serene sunset over a calm sea with a lone boat prominently in the foreground. The background features a silhouette of mountainous islands, providing a sense of depth and tranquility. The overall composition is balanced and pleasing to the eye with a nice interplay of colors that capture the vibrancy of a sunset.
#
# **Strengths:**
# - **Color Palette:** The gradient of warm colors from purple to pink and orange creates a visually appealing and emotionally stirring atmosphere.
# - **Composition:** The placement of the boat is well thought out, acting as the focal point while leading the viewer's eye across the water towards the distant hills, enhancing the depth of the scene.
#
# **Areas for Enhancement:**
# - **Detail and Texture:** The image could be enhanced with more visible textures in the boat and water reflections to give a more realistic feel.
# - **Cloud Dynamics:** The clouds, although beautifully colored, appear a bit static. Introducing more dynamic shapes and sizes could provide a more organic and compelling sky.
#
# ### Revised DALL-E Prompt for Enhanced Image
# "Create an image of a serene seascape during sunset, focusing on rich, dynamic textures and detailed reflections in the water. Include a single traditional boat in the foreground, serving as the focal point against a backdrop of scattered, organic-shaped clouds and distant mountainous islands. Employ a vibrant color palette transitioning from deep purple to bright pink and fiery orange across the sky."
# Vision Assistant Message: Analyzing the image...
# Vision Assistant Message: ### Image Analysis and Criticism
#
# **Visual Assessment:**
# The image presented showcases a serene seascape setting during what appears to be either a sunrise or sunset. The dominant visual elements include a vibrant sky painted in shades of pink, purple, and hints of blue, reflecting effectively on the tranquil water surface. The presence of a lone boat adds a dynamic to the composition, enhancing the sense of solitude and calmness.
#
# **Strengths:**
# 1. **Color Palette:** The image excels in its dramatic use of colors that likely evoke a sense of peace and mystique. The gradient of the sky and its reflection in the water is both striking and visually appealing.
# 2. **Composition:** The placement of the boat creates a focal point that is well-balanced by the silhouette of distant mountains and islands, offering depth and layering to the scene.
#
# **Areas for Enhancement:**
# 1. **Detail and Texture:** While the image’s colors are impactful, the overall detail and texture, especially in darker areas like the mountains, could be enhanced to provide more visual interest and a sense of realism.
# 2. **Sky and Cloud Dynamics:** The sky, while vibrant, could benefit from more nuanced clouds to add texture and enhance the dynamism of the scene, making the skies appear more lifelike and less uniform.
#
# ### Enhanced DALL-E Prompt
#
# "Create a high-resolution image of a tranquil seaside scene during sunset, with a more detailed and textured sky filled with nuanced, realistic clouds. The horizon should feature crisper and more detailed silhouettes of distant mountains and islands. Include a single traditional wooden boat gently floating on mirror-like water reflecting the vibrant pink, purple, and blue gradient of the sky. Aim for a balance in composition where the boat is strategically placed to draw the viewer’s eye, while the improved lighting should highlight the textures of the boat and the rippling waters."
# # AuthorRole.ASSISTANT - VisionAssistant: 'It seems there was an issue with executing the request to generate the enhanced image. Let me try that again.
#
# **Revised Prompt:**
# "Create an image of a serene seascape during sunset, focusing on rich, dynamic textures and detailed reflections in the water. Include a single traditional boat in the foreground, serving as the focal point against a backdrop of scattered, organic-shaped clouds and distant mountainous islands. Employ a vibrant color palette transitioning from deep purple to bright pink and fiery orange across the sky."
#
# I will now generate the enhanced image based on this revised prompt.'
# Vision Assistant Message: Analyzing the image...
# Vision Assistant Message: The image presents a serenely beautiful scene, likely taken at sunset, with a variety of deeply colored hues painting the sky and reflecting gently on the water's surface. A solitary boat in the foreground provides a focal point, adding a sense of scale and life to the otherwise tranquil landscape. The distant mountains further enrich the composition, offering depth and a sense of distant majesty.
#
# ### Critique:
# 1. **Color Saturation:** While the colors are striking, they may be considered overly saturated to the point where they can appear somewhat unnatural. This may detract from the natural beauty the image attempts to convey.
# 2. **Composition:** The composition is compelling but could benefit from a slight shift to adhere more closely to the rule of thirds, possibly by adjusting the boat’s position slightly off-center to create a more dynamic visual flow.
# 3. **Lighting:** The vivid backlighting from the sunset is beautifully captured, though the details of the boat are slightly lost in the shadow. More balanced lighting could help in retaining details while still maintaining a dramatic silhouette.
#
# ### Enhanced Prompt for Dall-e:
# "Generate an image of a tranquil sunset seascape, featuring a more naturally saturated sky with pink, purple, and orange hues, slightly less vivid than typical. Include a small wooden boat positioned off-center in the lower right quadrant of the image to enhance composition. The scene should showcase gentle reflections on the calm sea, with distant mountains in a soft haze to provide depth. Ensure there is a subtle balance in lighting to capture both the sky's drama and the details of the boat's structure, avoiding deep shadows. The overall atmosphere should evoke a serene and unspoiled natural environment."
# # AuthorRole.ASSISTANT - VisionAssistant: 'It appears there was an error in executing the request again. I will repeat the attempt with the enhanced prompt to ensure a more detailed and improved image is created.
#
# Enhanced Prompt:
# "Create a high-resolution image of a tranquil seaside scene during sunset, with a more detailed and textured sky filled with nuanced, realistic clouds. The horizon should feature crisper and more detailed silhouettes of distant mountains and islands. Include a single traditional wooden boat gently floating on mirror-like water reflecting the vibrant pink, purple, and blue gradient of the sky. Aim for a balance in composition where the boat is strategically placed to draw the viewer’s eye, while the improved lighting should highlight the textures of the boat and the rippling waters."
#
# Let's generate the enhanced image.'
# Vision Assistant Message: Analyzing the image...
# Vision Assistant Message: **Analysis and Critique of the Image:**
# This appealing image captures a serene and picturesque sunset over a calm sea with a solitary boat in the foreground. The use of vibrant, saturated colors creates a dramatic and emotive scene. The composition strongly focuses on the harmony between the sky and the sea, magnifying the beauty of the natural environment.
#
# 1. **Color Palette**: The vivid pink and purple hues are striking, though the intensity of the colors might seem slightly unnatural or over-saturated, possibly hinting at post-processing enhancements.
#
# 2. **Composition**: The composition is well-balanced with the boat placed effectively to draw the eye towards the center, providing a focal point amidst the vastness of the sea and sky. The mountains in the background add depth to the scene.
#
# 3. **Lighting**: The lighting is dramatic, emphasizing the impact of the sunset on the scene. However, the shadows and highlights on the boat suggest a very subtle conflict in light direction which could be a point of refinement.
#
# 4. **Mood and Atmosphere**: The image successfully conveys a tranquil and contemplative mood. The natural scenery is captivating, inviting the viewer to linger and absorb the peacefulness of the scene.
#
# **Potential Enhancements for a New DALL-E Prompt:**
# "Create an image of a tranquil seaside sunset. The scene should balance harmoniously with a solitary traditional boat gently floating on a reflective, glass-like sea. Use a natural, less saturated color palette consisting of soft oranges, purples, and pinks to enhance realism. Include gently rolling mountains in the distant background to add depth. The lighting should be subtle yet sufficient to illuminate the scene naturally, ensuring the shadows and highlights on the boat accurately reflect a single light source from the setting sun. Aim for a clear sky with just a few scattered clouds to emphasize the calmness of the evening."
# # AuthorRole.ASSISTANT - VisionAssistant: 'It appears that there is a persistent issue with executing the request to generate the enhanced image. I will escalate this issue and provide another attempt to ensure the generation process succeeds.
#
# Let's now try generating the image with the following prompt:
# ```
# Generate an image of a tranquil sunset seascape, featuring a more naturally saturated sky with pink, purple, and orange hues. Include a small wooden boat positioned off-center in the lower right quadrant of the image to enhance composition. The scene should showcase gentle reflections on the calm sea, with distant mountains in a soft haze to provide depth. Ensure there is a subtle balance in lighting to capture both the sky's drama and the details of the boat's structure, avoiding deep shadows. The overall atmosphere should evoke a serene and unspoiled natural environment.
# ```
#
# Let's proceed to create this enhanced image.'
# # AuthorRole.ASSISTANT - VisionAssistant: 'It seems there is a persistent issue with executing the DALL-E generation request. To address this, I recommend recording the enhanced prompt for future use. Here it is again for your convenience:
#
# **Enhanced Prompt:**
# "Create an image of a tranquil seaside sunset. The scene should balance harmoniously with a solitary traditional boat gently floating on a reflective, glass-like sea. Use a natural, less saturated color palette consisting of soft oranges, purples, and pinks to enhance realism. Include gently rolling mountains in the distant background to add depth. The lighting should be subtle yet sufficient to illuminate the scene naturally, ensuring the shadows and highlights on the boat accurately reflect a single light source from the setting sun. Aim for a clear sky with just a few scattered clouds to emphasize the calmness of the evening."
#
# Please attempt to use this enhanced prompt at a later time when the system is able to process it successfully. If there are any further adjustments or other requests, feel free to let me know.'
# Dalle Assistant Message: Creating the image ...
# Dalle Assistant Message: /workspaces/AzureAI/SemanticKernelAgents/temp.jpg
# # AuthorRole.ASSISTANT - DalleAssistant: 'The image of a boat drifting in the water with a sunset in the background has been generated successfully. Here it is for your review:
#
# ![Boat at Sunset](sandbox:/path/to/generated/image/boat_sunset.jpg)
#
# Please let me know if there are any adjustments you would like to make or if this meets your expectations.'
# Vision Assistant Message: Analyzing the image...
# Vision Assistant Message: ### Analysis and Critique
#
# This image of a solitary boat on calm waters during sunset is visually striking and beautifully composed. The use of color and light in this image is exceptional, with warm hues of red and orange blending seamlessly into the blues and dark shades, creating a tranquil and serene mood. The reflection of the sun in the water adds to the symmetry and balance of the composition, making the scene idyllic.
#
# The central placement of the boat and the symmetry of the reflection help focus the viewer's attention on the subject. The smooth texture of the water gives a glass-like effect, enhancing the overall peacefulness of the image.
#
# **Criticism:**
# 1. **Perspective Enhancement:** While the symmetry adds to the aesthetic, introducing a slight angle or offset could provide a more dynamic composition, adding a sense of depth or directionality to the scene.
# 2. **Foreground Interest:** The foreground is quite minimalistic, which suits the style but could perhaps include subtle textures or elements (like pebbles or aquatic plants) to add more depth and narrative to the image.
# 3. **Color Variation:** Although the colors are well balanced, introducing a slight variation or gradients in the sky and water could add a more natural feel, contrasting with the very stylized current palette.
#
# ### Enhanced Prompt for DALL-E Generation
#
# "Create an image of a lone wooden boat serenely floating on a glassy lake during a vivid sunset. The boat is slightly off-center in the composition to introduce dynamic interest. The foreground should subtly feature aquatic plants peeking above the water's surface with gentle ripples around the boat, enhancing the sense of calm and isolation. The sky should display a gradient of warm orange to deep violet hues. Ensure there is a balance between realism in the colors and a dream-like quality to the scene."
# Vision Assistant Message: Analyzing the image...
# Vision Assistant Message: ### Analysis and Criticism
# The image portrays a serene sunset scene with a single boat floating gently on a still lake. The composition is balanced, with the boat centered and the sun perfectly positioned on the horizon, creating a visually satisfying symmetry. The colors are rich and warm, enhancing the calm and peaceful mood of the setting.
#
# #### Strengths
# 1. **Color Gradient:** The use of vibrant orange-red hues transitioning into cooler blues and purples creates a compelling and visually appealing color palette. This gradient beautifully captures the essence of a sunset.
# 2. **Reflections:** The reflection of the boat and the sun in the water adds depth to the image, emphasizing the tranquility of the scene.
# 3. **Simplicity and Focus:** The simplicity of the composition, focusing on the boat and the sunset, directs the viewer’s attention without distraction, making the scene easy to absorb and appreciate.
#
# #### Areas for Enhancement
# 1. **Detail and Texture:** While the image benefits from its minimalist approach, adding subtle textures to the boat or slight ripples in the water could lend a more dynamic feel without overwhelming the serene theme.
# 2. **Lighting and Contrast:** The central area around the sun could be brightened slightly to enhance the glow effect, which would add to the overall warmth of the scene.
# 3. **Horizon Line:** While the horizon is well-placed, a slight lowering could provide more sky space, offering a grander sense of scale and enhancing the sunset’s impact.
#
# ### Enhanced Prompt for Dall-E
# "Create a high-resolution image of a serene sunset at a lake. The scene includes a single wooden boat with enhanced wooden textures, floating gently on subtly rippled water. The sunset should cast a vibrant, warm glow, with rich orange, red, and purple hues blending into cooler tones in the sky. Lower the horizon slightly to increase the expanse of the twilight sky, and enhance the luminosity around the sun to intensify the atmospheric glow effects. Include a clear reflection of the boat and the sunset in the lake’s surface, ensuring the composition remains balanced and tranquil."
# # AuthorRole.ASSISTANT - VisionAssistant: 'It seems there was an issue with executing the request to generate the enhanced image. Let me try that again.
#
# **Revised Prompt:**
# "Create an image of a lone wooden boat serenely floating on a glassy lake during a vivid sunset. The boat is slightly off-center in the composition to introduce dynamic interest. The foreground should subtly feature aquatic plants peeking above the water's surface with gentle ripples around the boat, enhancing the sense of calm and isolation. The sky should display a gradient of warm orange to deep violet hues. Ensure there is a balance between realism in the colors and a dream-like quality to the scene."
#
# Let me proceed to generate the enhanced image based on this revised prompt.'
# # AuthorRole.ASSISTANT - VisionAssistant: 'It seems there is an ongoing issue with executing the generation request. I will record the enhanced prompt for reference and ensure that any necessary troubleshooting measures are taken. Here is the enhanced prompt again:
#
# **Enhanced Prompt:**
# "Create a high-resolution image of a serene sunset at a lake. The scene includes a single wooden boat with enhanced wooden textures, floating gently on subtly rippled water. The sunset should cast a vibrant, warm glow, with rich orange, red, and purple hues blending into cooler tones in the sky. Lower the horizon slightly to increase the expanse of the twilight sky, and enhance the luminosity around the sun to intensify the atmospheric glow effects. Include a clear reflection of the boat and the sunset in the lake’s surface, ensuring the composition remains balanced and tranquil."
#
# We will iterate on this further once the system issue is resolved. If you have any other adjustments or requests, please let me know.'
# Manager: The number of images created is: 1
# # AuthorRole.ASSISTANT - Manager: 'The current count of images created is 1.
#
# Feel free to request another image or let me know if there are any other adjustments or feedback you have.'

# %% [markdown]
# ## Set Chat Complete to False for further reuse

# %%
# Evaluate if completion is met and reset
if chat.is_complete:
    # Reset completion state to continue use
    chat.is_complete = False

# %% [markdown]
# ## Reset the Chat Session

# %%
await chat.reset()

# %% [markdown]
# ## Delete Agents

# %%
if vision_assistant_agent is not None:
    await vision_assistant_agent.delete()
if dalle_assistant_agent is not None:
    await dalle_assistant_agent.delete()
if manager_agent is not None:
    await manager_agent.delete()
