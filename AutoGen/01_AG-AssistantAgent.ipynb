# %% [markdown]
# # AutoGen Assistant Agent

# %% [markdown]
# ## Install Library

# %%
# %pip install "autogen-agentchat==0.4.0.dev13" "autogen-ext[openai,azure,docker]==0.4.0.dev13"
# Out:
# Collecting autogen-agentchat==0.4.0.dev13
#   Using cached autogen_agentchat-0.4.0.dev13-py3-none-any.whl.metadata (1.8 kB)
# Collecting autogen-ext==0.4.0.dev13 (from autogen-ext[azure,docker,openai]==0.4.0.dev13)
#   Using cached autogen_ext-0.4.0.dev13-py3-none-any.whl.metadata (3.1 kB)
# Collecting autogen-core==0.4.0.dev13 (from autogen-agentchat==0.4.0.dev13)
#   Using cached autogen_core-0.4.0.dev13-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: azure-core in /home/codespace/.python/current/lib/python3.12/site-packages (from autogen-ext[azure,docker,openai]==0.4.0.dev13) (1.32.0)
# Requirement already satisfied: azure-identity in /home/codespace/.python/current/lib/python3.12/site-packages (from autogen-ext[azure,docker,openai]==0.4.0.dev13) (1.19.0)
# Requirement already satisfied: docker~=7.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from autogen-ext[azure,docker,openai]==0.4.0.dev13) (7.1.0)
# Requirement already satisfied: aiofiles in /home/codespace/.python/current/lib/python3.12/site-packages (from autogen-ext[azure,docker,openai]==0.4.0.dev13) (24.1.0)
# Requirement already satisfied: openai>=1.52.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from autogen-ext[azure,docker,openai]==0.4.0.dev13) (1.68.2)
# Requirement already satisfied: aioconsole>=0.8.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (0.8.1)
# Requirement already satisfied: aiohttp>=3.10.10 in /home/codespace/.python/current/lib/python3.12/site-packages (from autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (3.11.16)
# Requirement already satisfied: asyncio-atexit in /home/codespace/.python/current/lib/python3.12/site-packages (from autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (1.0.1)
# Requirement already satisfied: jsonref~=1.1.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (1.1.0)
# Collecting opentelemetry-api~=1.27.0 (from autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13)
#   Using cached opentelemetry_api-1.27.0-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: pillow>=11.0.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (11.1.0)
# Collecting protobuf~=4.25.1 (from autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13)
#   Downloading protobuf-4.25.6-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (2.10.4)
# Requirement already satisfied: tiktoken>=0.8.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (0.8.0)
# Requirement already satisfied: typing-extensions in /home/codespace/.python/current/lib/python3.12/site-packages (from autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (4.12.2)
# Requirement already satisfied: requests>=2.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from docker~=7.0->autogen-ext[azure,docker,openai]==0.4.0.dev13) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from docker~=7.0->autogen-ext[azure,docker,openai]==0.4.0.dev13) (2.2.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from openai>=1.52.2->autogen-ext[azure,docker,openai]==0.4.0.dev13) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from openai>=1.52.2->autogen-ext[azure,docker,openai]==0.4.0.dev13) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/codespace/.local/lib/python3.12/site-packages (from openai>=1.52.2->autogen-ext[azure,docker,openai]==0.4.0.dev13) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from openai>=1.52.2->autogen-ext[azure,docker,openai]==0.4.0.dev13) (0.8.2)
# Requirement already satisfied: sniffio in /home/codespace/.local/lib/python3.12/site-packages (from openai>=1.52.2->autogen-ext[azure,docker,openai]==0.4.0.dev13) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/codespace/.python/current/lib/python3.12/site-packages (from openai>=1.52.2->autogen-ext[azure,docker,openai]==0.4.0.dev13) (4.67.1)
# Requirement already satisfied: six>=1.11.0 in /home/codespace/.local/lib/python3.12/site-packages (from azure-core->autogen-ext[azure,docker,openai]==0.4.0.dev13) (1.16.0)
# Requirement already satisfied: cryptography>=2.5 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-identity->autogen-ext[azure,docker,openai]==0.4.0.dev13) (44.0.2)
# Requirement already satisfied: msal>=1.30.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-identity->autogen-ext[azure,docker,openai]==0.4.0.dev13) (1.31.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from azure-identity->autogen-ext[azure,docker,openai]==0.4.0.dev13) (1.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from aiohttp>=3.10.10->autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from aiohttp>=3.10.10->autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from aiohttp>=3.10.10->autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from aiohttp>=3.10.10->autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/codespace/.python/current/lib/python3.12/site-packages (from aiohttp>=3.10.10->autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from aiohttp>=3.10.10->autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from aiohttp>=3.10.10->autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (1.18.3)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai>=1.52.2->autogen-ext[azure,docker,openai]==0.4.0.dev13) (3.10)
# Requirement already satisfied: cffi>=1.12 in /home/codespace/.local/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity->autogen-ext[azure,docker,openai]==0.4.0.dev13) (1.17.1)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>=1.52.2->autogen-ext[azure,docker,openai]==0.4.0.dev13) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>=1.52.2->autogen-ext[azure,docker,openai]==0.4.0.dev13) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.52.2->autogen-ext[azure,docker,openai]==0.4.0.dev13) (0.14.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->autogen-ext[azure,docker,openai]==0.4.0.dev13) (2.10.1)
# Requirement already satisfied: portalocker<3,>=1.4 in /home/codespace/.python/current/lib/python3.12/site-packages (from msal-extensions>=1.2.0->azure-identity->autogen-ext[azure,docker,openai]==0.4.0.dev13) (2.10.1)
# Requirement already satisfied: deprecated>=1.2.6 in /home/codespace/.python/current/lib/python3.12/site-packages (from opentelemetry-api~=1.27.0->autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from opentelemetry-api~=1.27.0->autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (8.4.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.26.0->docker~=7.0->autogen-ext[azure,docker,openai]==0.4.0.dev13) (3.3.2)
# Requirement already satisfied: regex>=2022.1.18 in /home/codespace/.python/current/lib/python3.12/site-packages (from tiktoken>=0.8.0->autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (2024.11.6)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity->autogen-ext[azure,docker,openai]==0.4.0.dev13) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/codespace/.python/current/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api~=1.27.0->autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (1.17.0)
# Requirement already satisfied: zipp>=0.5 in /home/codespace/.python/current/lib/python3.12/site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api~=1.27.0->autogen-core==0.4.0.dev13->autogen-agentchat==0.4.0.dev13) (3.21.0)
# WARNING: The candidate selected for download or install is a yanked version: 'autogen-agentchat' candidate (version 0.4.0.dev13 at https://files.pythonhosted.org/packages/71/ad/dae777700713535a7e8becec475d98074c00dad76aec13352b03322f385a/autogen_agentchat-0.4.0.dev13-py3-none-any.whl (from https://pypi.org/simple/autogen-agentchat/) (requires-python:>=3.10))
# Reason for being yanked: This version accidentally included an unintentional GPL dependency. Please upgrade to 0.4.2.
# WARNING: The candidate selected for download or install is a yanked version: 'autogen-ext' candidate (version 0.4.0.dev13 at https://files.pythonhosted.org/packages/ba/c0/ccb0697da21402e4effaf15cca000705f2d64d5820961b05ad3f50d3c684/autogen_ext-0.4.0.dev13-py3-none-any.whl (from https://pypi.org/simple/autogen-ext/) (requires-python:>=3.10))
# Reason for being yanked: This version accidentally included an unintentional GPL dependency. Please upgrade to 0.4.2.
# WARNING: The candidate selected for download or install is a yanked version: 'autogen-core' candidate (version 0.4.0.dev13 at https://files.pythonhosted.org/packages/d3/75/8472f6db7b964f02d5e270deffd80181b8bfd357dfbd6eb08bc3b8ee2210/autogen_core-0.4.0.dev13-py3-none-any.whl (from https://pypi.org/simple/autogen-core/) (requires-python:>=3.10))
# Reason for being yanked: This version accidentally included an unintentional GPL dependency. Please upgrade to 0.4.2.
# Using cached autogen_agentchat-0.4.0.dev13-py3-none-any.whl (60 kB)
# Using cached autogen_ext-0.4.0.dev13-py3-none-any.whl (110 kB)
# Using cached autogen_core-0.4.0.dev13-py3-none-any.whl (70 kB)
# Using cached opentelemetry_api-1.27.0-py3-none-any.whl (63 kB)
# Downloading protobuf-4.25.6-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Installing collected packages: protobuf, opentelemetry-api, autogen-core, autogen-ext, autogen-agentchat
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Uninstalling protobuf-5.29.4:
#       Successfully uninstalled protobuf-5.29.4
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.31.1
#     Uninstalling opentelemetry-api-1.31.1:
#       Successfully uninstalled opentelemetry-api-1.31.1
#   Attempting uninstall: autogen-core
#     Found existing installation: autogen-core 0.4.2
#     Uninstalling autogen-core-0.4.2:
#       Successfully uninstalled autogen-core-0.4.2
#   Attempting uninstall: autogen-ext
#     Found existing installation: autogen-ext 0.4.2
#     Uninstalling autogen-ext-0.4.2:
#       Successfully uninstalled autogen-ext-0.4.2
#   Attempting uninstall: autogen-agentchat
#     Found existing installation: autogen-agentchat 0.4.2
#     Uninstalling autogen-agentchat-0.4.2:
#       Successfully uninstalled autogen-agentchat-0.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-semantic-conventions 0.52b1 requires opentelemetry-api==1.31.1, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-cohere 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-sdk 1.31.1 requires opentelemetry-api==1.31.1, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-asgi 0.50b0 requires opentelemetry-instrumentation==0.50b0, but you have opentelemetry-instrumentation 0.52b1 which is incompatible.
# opentelemetry-instrumentation-asgi 0.50b0 requires opentelemetry-semantic-conventions==0.50b0, but you have opentelemetry-semantic-conventions 0.52b1 which is incompatible.
# opentelemetry-instrumentation-asgi 0.50b0 requires opentelemetry-util-http==0.50b0, but you have opentelemetry-util-http 0.52b1 which is incompatible.
# opentelemetry-instrumentation-watsonx 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-openai 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# uptrace 1.31.0 requires opentelemetry-api~=1.31.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-langchain 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-together 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-fastapi 0.50b0 requires opentelemetry-instrumentation==0.50b0, but you have opentelemetry-instrumentation 0.52b1 which is incompatible.
# opentelemetry-instrumentation-fastapi 0.50b0 requires opentelemetry-semantic-conventions==0.50b0, but you have opentelemetry-semantic-conventions 0.52b1 which is incompatible.
# opentelemetry-instrumentation-fastapi 0.50b0 requires opentelemetry-util-http==0.50b0, but you have opentelemetry-util-http 0.52b1 which is incompatible.
# grpcio-status 1.68.1 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.6 which is incompatible.
# opentelemetry-instrumentation-milvus 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-chromadb 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# grpcio-health-checking 1.69.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.6 which is incompatible.
# promptflow-devkit 1.16.2 requires pillow<11.0.0,>=10.1.0, but you have pillow 11.1.0 which is incompatible.
# traceloop-sdk 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-pinecone 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-alephalpha 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-weaviate 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-ollama 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-mistralai 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-vertexai 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-google-generativeai 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-lancedb 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-marqo 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-llamaindex 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-anthropic 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-proto 1.31.1 requires protobuf<6.0,>=5.0, but you have protobuf 4.25.6 which is incompatible.
# opentelemetry-instrumentation-groq 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-qdrant 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-crewai 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-transformers 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-replicate 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# grpcio-tools 1.69.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.6 which is incompatible.
# opentelemetry-instrumentation-bedrock 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# opentelemetry-instrumentation-haystack 0.39.0 requires opentelemetry-api<2.0.0,>=1.28.0, but you have opentelemetry-api 1.27.0 which is incompatible.
# Successfully installed autogen-agentchat-0.4.0.dev13 autogen-core-0.4.0.dev13 autogen-ext-0.4.0.dev13 opentelemetry-api-1.27.0 protobuf-4.25.6
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load Azure Configuration

# %%
from dotenv import load_dotenv
import os

azure_openai_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
azure_openai_key = os.getenv("AZURE_OPENAI_API_KEY")
azure_openai_deployment = os.getenv("AZURE_OPENAI_CHAT_DEPLOYMENT_NAME")
azure_openai_api_version = os.getenv("AZURE_OPENAI_API_VERSION")

# %% [markdown]
# ## Create Azure OpenAI Client
# Using the model client class

# %%
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
from azure.identity import DefaultAzureCredential, get_bearer_token_provider

# Create the token provider
#token_provider = get_bearer_token_provider(DefaultAzureCredential(), "https://cognitiveservices.azure.com/.default")

az_model_client = AzureOpenAIChatCompletionClient(
    azure_deployment=azure_openai_deployment,
    model=azure_openai_deployment,
    api_version=azure_openai_api_version,
    azure_endpoint=azure_openai_endpoint,
    # azure_ad_token_provider=token_provider,  # Optional if you choose key-based authentication.
    api_key=azure_openai_key, # For key-based authentication.
)

# %% [markdown]
# ## Defining an Agent
# AssistantAgent is a built-in agent that uses a language model and has the ability to use tools.

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.ui import Console
from autogen_core import CancellationToken

# Define a tool
async def get_weather(city: str) -> str:
    return f"The weather in {city} is 73 degrees and Sunny."

# Define an agent
weather_agent = AssistantAgent(
    name="weather_agent",
    description="This agent provides weather information.",
    model_client=az_model_client,
    tools=[get_weather],
    system_message="""
    You are agent that assists with weather information.
    If you are given an image, you will identify the city in the image and provide the weather information. 
    If you are asked about other topics, tell the user you can only provide weather information.
    """,
)

# %% [markdown]
# ## Text Message
# Create a text message, which accepts a string content and a string source

# %%
from autogen_agentchat.messages import TextMessage

text_message = TextMessage(content="What's the weather in Chicago", source="User")

# Run the team and stream messages to the console.
stream = weather_agent.run_stream(task=text_message)
await Console(stream)
# Out:
# ---------- User ----------
# What's the weather in Chicago
# ---------- weather_agent ----------
# [FunctionCall(id='call_x1CAkpgGfUFSV6MYMSc4GlXn', arguments='{"city":"Chicago"}', name='get_weather')]
# [Prompt tokens: 104, Completion tokens: 15]
# ---------- weather_agent ----------
# [FunctionExecutionResult(content='The weather in Chicago is 73 degrees and Sunny.', call_id='call_x1CAkpgGfUFSV6MYMSc4GlXn')]
# ---------- weather_agent ----------
# The weather in Chicago is 73 degrees and Sunny.
# ---------- Summary ----------
# Number of messages: 4
# Finish reason: None
# Total prompt tokens: 104
# Total completion tokens: 15
# Duration: 1.19 seconds
# /home/codespace/.python/current/lib/python3.12/site-packages/autogen_agentchat/agents/_assistant_agent.py:343: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-05-13. Model mapping may be incorrect.
#   result = await self._model_client.create(
# TaskResult(messages=[TextMessage(source='User', models_usage=None, content="What's the weather in Chicago", type='TextMessage'), ToolCallRequestEvent(source='weather_agent', models_usage=RequestUsage(prompt_tokens=104, completion_tokens=15), content=[FunctionCall(id='call_x1CAkpgGfUFSV6MYMSc4GlXn', arguments='{"city":"Chicago"}', name='get_weather')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(source='weather_agent', models_usage=None, content=[FunctionExecutionResult(content='The weather in Chicago is 73 degrees and Sunny.', call_id='call_x1CAkpgGfUFSV6MYMSc4GlXn')], type='ToolCallExecutionEvent'), ToolCallSummaryMessage(source='weather_agent', models_usage=None, content='The weather in Chicago is 73 degrees and Sunny.', type='ToolCallSummaryMessage')], stop_reason=None)

# %% [markdown]
# ## MultiModal Message

# %%
from autogen_agentchat.messages import MultiModalMessage
from autogen_core import Image as AGImage
from PIL import Image
from matplotlib import pyplot as plt
import cv2

img_path = "../Data/images/empirestate.jpeg"

# Load the image using OpenCV.
img = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
# Convert the image from BGR to RGB for displaying with matplotlib, because OpenCV uses BGR by default and matplotlib expects RGB.
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image with matplotlib.
plt.imshow(img_rgb)
plt.axis("off")  # Turn off axis labels.
plt.show()

raw_image = Image.open(img_path)
# Create an AGImage object from the raw image.
img = AGImage(raw_image)
multi_modal_message = MultiModalMessage(content=["What's the weather in this image?", img], source="User")

# Run the team and stream messages to the console.
stream = weather_agent.run_stream(task=multi_modal_message)
await Console(stream)
# Out:
# ---------- User ----------
# What's the weather in this image?
#
# ---------- weather_agent ----------
# [FunctionCall(id='call_oyBOgWVteCUq6madjHRt0EbJ', arguments='{"city":"New York"}', name='get_weather')]
# [Prompt tokens: 1258, Completion tokens: 15]
# ---------- weather_agent ----------
# [FunctionExecutionResult(content='The weather in New York is 73 degrees and Sunny.', call_id='call_oyBOgWVteCUq6madjHRt0EbJ')]
# ---------- weather_agent ----------
# The weather in New York is 73 degrees and Sunny.
# ---------- Summary ----------
# Number of messages: 4
# Finish reason: None
# Total prompt tokens: 1258
# Total completion tokens: 15
# Duration: 11.79 seconds
# /home/codespace/.python/current/lib/python3.12/site-packages/autogen_agentchat/agents/_assistant_agent.py:343: UserWarning: Resolved model mismatch: gpt-4o-2024-08-06 != gpt-4o-2024-05-13. Model mapping may be incorrect.
#   result = await self._model_client.create(
# TaskResult(messages=[MultiModalMessage(source='User', models_usage=None, content=["What's the weather in this image?", <autogen_core._image.Image object at 0x7423e0828200>], type='MultiModalMessage'), ToolCallRequestEvent(source='weather_agent', models_usage=RequestUsage(prompt_tokens=1258, completion_tokens=15), content=[FunctionCall(id='call_oyBOgWVteCUq6madjHRt0EbJ', arguments='{"city":"New York"}', name='get_weather')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(source='weather_agent', models_usage=None, content=[FunctionExecutionResult(content='The weather in New York is 73 degrees and Sunny.', call_id='call_oyBOgWVteCUq6madjHRt0EbJ')], type='ToolCallExecutionEvent'), ToolCallSummaryMessage(source='weather_agent', models_usage=None, content='The weather in New York is 73 degrees and Sunny.', type='ToolCallSummaryMessage')], stop_reason=None)

# %% [markdown]
# ## Agents have State

# %%
text_message = TextMessage(content="What were the cities again that I asked about the weather?", source="User")

# Run the team and stream messages to the console.
stream = weather_agent.run_stream(task=text_message)
await Console(stream)
# Out:
# ---------- User ----------
# What were the cities again that I asked about the weather?
# ---------- weather_agent ----------
# You asked about the weather in Chicago and New York.
# [Prompt tokens: 1314, Completion tokens: 12]
# ---------- Summary ----------
# Number of messages: 2
# Finish reason: None
# Total prompt tokens: 1314
# Total completion tokens: 12
# Duration: 11.59 seconds
# TaskResult(messages=[TextMessage(source='User', models_usage=None, content='What were the cities again that I asked about the weather?', type='TextMessage'), TextMessage(source='weather_agent', models_usage=RequestUsage(prompt_tokens=1314, completion_tokens=12), content='You asked about the weather in Chicago and New York.', type='TextMessage')], stop_reason=None)

# %% [markdown]
# ## Getting Responses

# %% [markdown]
# 1. on_messages() method returns a Response that contains the following attributes:
# - chat_message: contains agent’s final response
# - inner_messages: stores the agent’s “thought process” that led to the final response.
# 2. on_messages() will update the internal state of the agent – it will add the messages to the agent’s history.
# - You should call this method with new messages.
# - You should NOT repeatedly call this method with the same messages or the complete history.

# %%
img_path = "../Data/images/mtfuji.jpeg"

img = cv2.imread(img_path, cv2.IMREAD_UNCHANGED)
# Convert the image from BGR to RGB for displaying with matplotlib, because OpenCV uses BGR by default and matplotlib expects RGB.
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image with matplotlib.
plt.imshow(img_rgb)
plt.axis("off")  # Turn off axis labels.
plt.show()

raw_image = Image.open(img_path )
# Create an AGImage object from the raw image.
img = AGImage(raw_image)
multi_modal_message = MultiModalMessage(content=["What's the city where this image is located? Provide the weather there.", img], source="User")

cancellation_token=CancellationToken()
response = await weather_agent.on_messages(
    [multi_modal_message],
    cancellation_token=cancellation_token,
)
# contains the agent's "thought process"
print("Thought process: ")
print(response.inner_messages)
print("\n")
# contains the agent's final response
print("Final Response: ")
print(response.chat_message)
print("\n")
print("Final Response Content: ")
print(response.chat_message.content)
# Out:
# Thought process:
# [ToolCallRequestEvent(source='weather_agent', models_usage=RequestUsage(prompt_tokens=3618, completion_tokens=45), content=[FunctionCall(id='call_t9xY7Ywqbt52opWvTgwjcwjR', arguments='{"city":"Fuji"}', name='get_weather')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(source='weather_agent', models_usage=None, content=[FunctionExecutionResult(content='The weather in Fuji is 73 degrees and Sunny.', call_id='call_t9xY7Ywqbt52opWvTgwjcwjR')], type='ToolCallExecutionEvent')]
#
#
# Final Response:
# source='weather_agent' models_usage=None content='The weather in Fuji is 73 degrees and Sunny.' type='ToolCallSummaryMessage'
#
#
# Final Response Content:
# The weather in Fuji is 73 degrees and Sunny.

# %% [markdown]
# ## Streaming Messages
# We can also stream each message as it is generated by the agent by using the on_messages_stream() method, and use Console to print the messages as they appear to the console.

# %%
text_message = TextMessage(content="What were the cities again that I asked about the weather?", source="User")

from IPython.display import display

cancellation_token=CancellationToken()
await Console(weather_agent.on_messages_stream(
        [text_message],
        cancellation_token=cancellation_token,)
    )
# Out:
# ---------- weather_agent ----------
# You asked about the weather in Tokyo and Fuji.
# [Prompt tokens: 3673, Completion tokens: 11]
# ---------- Summary ----------
# Number of inner messages: 0
# Total prompt tokens: 3673
# Total completion tokens: 11
# Duration: 20.75 seconds
# Response(chat_message=TextMessage(source='weather_agent', models_usage=RequestUsage(prompt_tokens=3673, completion_tokens=11), content='You asked about the weather in Tokyo and Fuji.', type='TextMessage'), inner_messages=[])

# %% [markdown]
# ## Reset Agent to Initial State
#
# Using on_reset

# %%
cancellation_token=CancellationToken()
# Reset the agent
await weather_agent.on_reset(cancellation_token=cancellation_token)

text_message = TextMessage(content="What were the cities again that I asked about the weather?", source="User")
response = await weather_agent.on_messages(
        [text_message],
        cancellation_token=cancellation_token,
    )
print(response.chat_message.content)

# Reset the agent again
await weather_agent.on_reset(cancellation_token=cancellation_token)
# Out:
# I can only provide weather information. If you need weather updates for a specific city, please provide the city name, and I'll get that information for you.

# %% [markdown]
# ## Using Model Context
# AssistantAgent has a model_context parameter that can be used to pass in a ChatCompletionContext object. This allows the agent to use different model contexts, such as BufferedChatCompletionContext to limit the context sent to the model.
#
# By default, AssistantAgent uses the UnboundedChatCompletionContext which sends the full conversation history to the model. To limit the context to the last n messages, you can use the BufferedChatCompletionContext.

# %%
from autogen_core.model_context import BufferedChatCompletionContext
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.ui import Console
from autogen_core import CancellationToken
from autogen_agentchat.messages import TextMessage

# Define a tool
async def get_weather(city: str) -> str:
    return f"The weather in {city} is 73 degrees and Sunny."

# Define an agent
weather_agent = AssistantAgent(
    name="weather_agent",
    description="This agent provides weather information.",
    model_client=az_model_client,
    tools=[get_weather],
    system_message="""
    You are agent that assists with weather information.
    """,
    model_context=BufferedChatCompletionContext(buffer_size=8),  
)

# %%
text_message = TextMessage(content="What is the weather in Chicago?", source="User")
stream = weather_agent.run_stream(task=text_message)
await Console(stream)
print("\n")

text_message = TextMessage(content="How about in New York?", source="User")
stream = weather_agent.run_stream(task=text_message)
await Console(stream)
print("\n")

text_message = TextMessage(content="What's it like in Tokyo?", source="User")
stream = weather_agent.run_stream(task=text_message)
await Console(stream)
print("\n")
# Out:
# ---------- User ----------
# What is the weather in Chicago?
# ---------- weather_agent ----------
# [FunctionCall(id='call_PO6NPjhAYOduf1d6ktuBi2Bq', arguments='{"city":"Chicago"}', name='get_weather')]
# [Prompt tokens: 64, Completion tokens: 15]
# ---------- weather_agent ----------
# [FunctionExecutionResult(content='The weather in Chicago is 73 degrees and Sunny.', call_id='call_PO6NPjhAYOduf1d6ktuBi2Bq')]
# ---------- weather_agent ----------
# The weather in Chicago is 73 degrees and Sunny.
# ---------- Summary ----------
# Number of messages: 4
# Finish reason: None
# Total prompt tokens: 64
# Total completion tokens: 15
# Duration: 0.67 seconds
#
#
# ---------- User ----------
# How about in New York?
# ---------- weather_agent ----------
# [FunctionCall(id='call_YFdSZlvTSVB7NvDR9RSIQdWi', arguments='{"city":"New York"}', name='get_weather')]
# [Prompt tokens: 112, Completion tokens: 16]
# ---------- weather_agent ----------
# [FunctionExecutionResult(content='The weather in New York is 73 degrees and Sunny.', call_id='call_YFdSZlvTSVB7NvDR9RSIQdWi')]
# ---------- weather_agent ----------
# The weather in New York is 73 degrees and Sunny.
# ---------- Summary ----------
# Number of messages: 4
# Finish reason: None
# Total prompt tokens: 112
# Total completion tokens: 16
# Duration: 1.54 seconds
#
#
# ---------- User ----------
# What's it like in Tokyo?
# ---------- weather_agent ----------
# [FunctionCall(id='call_oyz61m6XU0rbKjAxEX3vynBv', arguments='{"city":"Tokyo"}', name='get_weather')]
# [Prompt tokens: 162, Completion tokens: 15]
# ---------- weather_agent ----------
# [FunctionExecutionResult(content='The weather in Tokyo is 73 degrees and Sunny.', call_id='call_oyz61m6XU0rbKjAxEX3vynBv')]
# ---------- weather_agent ----------
# The weather in Tokyo is 73 degrees and Sunny.
# ---------- Summary ----------
# Number of messages: 4
# Finish reason: None
# Total prompt tokens: 162
# Total completion tokens: 15
# Duration: 0.40 seconds

# %%
text_message = TextMessage(content="What was the weather in the first city again?", source="User")
stream = weather_agent.run_stream(task=text_message)
await Console(stream)
print("\n")

## New York is the first city in the context given that each interaction was 4 messages.
# Out:
# ---------- User ----------
# What was the weather in the first city again?
# ---------- weather_agent ----------
# The weather in New York is 73 degrees and Sunny.
# [Prompt tokens: 165, Completion tokens: 14]
# ---------- Summary ----------
# Number of messages: 2
# Finish reason: None
# Total prompt tokens: 165
# Total completion tokens: 14
# Duration: 0.76 seconds

# %% [markdown]
# # Save and Load Agent State

# %%
import json

state = await weather_agent.save_state()

# (Optional) Write state to disk.
with open("assistant_state.json", "w") as f:
    json.dump(state, f)

# (Optional) Load it back from disk.
with open("assistant_state.json", "r") as f:
    state = json.load(f)
    print(state) # Inspect the state, which contains the chat history.

# Carry on the chat.
response = await weather_agent.on_messages([TextMessage(content="What is the weather in Rome?", source="user")], cancellation_token=CancellationToken())
print(response.chat_message.content)
# Out:
# {'type': 'AssistantAgentState', 'version': '1.0.0', 'llm_context': {'messages': [{'content': 'What is the weather in Chicago?', 'source': 'User', 'type': 'UserMessage'}, {'content': [{'id': 'call_PO6NPjhAYOduf1d6ktuBi2Bq', 'arguments': '{"city":"Chicago"}', 'name': 'get_weather'}], 'source': 'weather_agent', 'type': 'AssistantMessage'}, {'content': [{'content': 'The weather in Chicago is 73 degrees and Sunny.', 'call_id': 'call_PO6NPjhAYOduf1d6ktuBi2Bq'}], 'type': 'FunctionExecutionResultMessage'}, {'content': 'How about in New York?', 'source': 'User', 'type': 'UserMessage'}, {'content': [{'id': 'call_YFdSZlvTSVB7NvDR9RSIQdWi', 'arguments': '{"city":"New York"}', 'name': 'get_weather'}], 'source': 'weather_agent', 'type': 'AssistantMessage'}, {'content': [{'content': 'The weather in New York is 73 degrees and Sunny.', 'call_id': 'call_YFdSZlvTSVB7NvDR9RSIQdWi'}], 'type': 'FunctionExecutionResultMessage'}, {'content': "What's it like in Tokyo?", 'source': 'User', 'type': 'UserMessage'}, {'content': [{'id': 'call_oyz61m6XU0rbKjAxEX3vynBv', 'arguments': '{"city":"Tokyo"}', 'name': 'get_weather'}], 'source': 'weather_agent', 'type': 'AssistantMessage'}, {'content': [{'content': 'The weather in Tokyo is 73 degrees and Sunny.', 'call_id': 'call_oyz61m6XU0rbKjAxEX3vynBv'}], 'type': 'FunctionExecutionResultMessage'}, {'content': 'What was the weather in the first city again?', 'source': 'User', 'type': 'UserMessage'}, {'content': 'The weather in New York is 73 degrees and Sunny.', 'source': 'weather_agent', 'type': 'AssistantMessage'}, {'content': 'What is the weather in Rome?', 'source': 'user', 'type': 'UserMessage'}, {'content': [{'id': 'call_wJRNERQTdTkgacKUkLiJWKFY', 'arguments': '{"city":"Rome"}', 'name': 'get_weather'}], 'source': 'weather_agent', 'type': 'AssistantMessage'}, {'content': [{'content': 'The weather in Rome is 73 degrees and Sunny.', 'call_id': 'call_wJRNERQTdTkgacKUkLiJWKFY'}], 'type': 'FunctionExecutionResultMessage'}, {'content': 'What was the weather in the first city again?', 'source': 'user', 'type': 'UserMessage'}, {'content': 'The weather in New York is 64 degrees and Cloudy.', 'source': 'weather_agent', 'type': 'AssistantMessage'}]}}
# The weather in Rome is 73 degrees and Sunny.

# %%
# Carry on the same chat again.
response = await weather_agent.on_messages([TextMessage(content="What was the weather in the first city again?", source="user")], cancellation_token=CancellationToken())
print(response.chat_message.content)
# Out:
# The weather in New York is 64 degrees and Cloudy.

# %%
# Load the state, resulting the agent to revert to the previous state before the last message.
await weather_agent.load_state(state)

# Carry on the same chat again.
response = await weather_agent.on_messages([TextMessage(content="What was the weather in the first city again?", source="user")], cancellation_token=CancellationToken())
print(response.chat_message.content)
# Out:
# The weather in Rome is 73 degrees and sunny.
